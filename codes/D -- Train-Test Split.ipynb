# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Capstone Project: Deep Fakes Detector

# %% [markdown]
# ## Background

# %% [markdown]
# Deep fakes (a combination of "[*deep learning*](https://en.wikipedia.org/wiki/Deep_learning)" and "fake") are synthetic media in which a person in an existing image or video is replaced with someone similar. While the creation of fake content is not new, deep fakes leverage powerful techniques from artificial intelligence and machine learning to produce audio and/or visual content that can more easily deceive.
#
# The main machine learning methods used to create deep fakes are based on deep learning and involve training generative neural network architectures, such as [*generative adversarial networks (GANs)*](https://en.wikipedia.org/wiki/Generative_adversarial_network).
#
# Deep fakes have many potential applications across multiple industries and domains, including but not limited to:
#  - [*Art*](https://digitalsynopsis.com/design/samsung-living-portrait/)
#  - [*Charity*](https://abcnews.go.com/International/david-beckham-speaks-languages-campaign-end-malaria/story?id=62270227)
#  - [*Entertainment*](https://youtu.be/mPU0WNUzsBo)
#  - [*Gaming*](https://www.theverge.com/2018/12/3/18121198/ai-generated-video-game-graphics-nvidia-driving-demo-neurips)
#  - [*Healthcare*](https://www.fastcompany.com/90240746/deepfakes-for-good-why-researchers-are-using-ai-for-synthetic-health-data)
#  - [*History*](https://www.theverge.com/2019/5/10/18540953/salvador-dali-lives-deepfake-museum)
#  - [*Public Service*](https://youtu.be/cQ54GDm1eL0)
#  - etc.
#
# However, deep fakes garnered widespread attention for their uses in creating child sexual abuse material, [*celebrity pornographic videos*](https://www.highsnobiety.com/p/what-are-deepfakes-ai-porn/), [*revenge porn*](https://en.wikipedia.org/wiki/Revenge_porn), [*fake news*](https://en.wikipedia.org/wiki/Fake_news), hoaxes, bullying, financial fraud, etc. This has elicited responses from both industry ([*Source*](https://thenextweb.com/news/twitter-pornhub-and-other-platforms-ban-ai-generated-celebrity-porn)) and government ([*Source*](https://www.congress.gov/bill/116th-congress/house-bill/3230)) to detect and limit their use. In a July 2021 study commissioned by the Panel for the Future of Science and Technology, Scientific Foresight Unit (STOA), European Parliament titled "[*Tackling deepfakes in European policy*](https://www.europarl.europa.eu/thinktank/en/document/EPRS_STU(2021)690039)", the authors highlighted similar concerns and more (See Table below):
#
# **Overview of different types of risks associated with deepfakes**
#
# | **Psychological Harm** | **Financial Harm**             | **Societal Harm**                 |
# |------------------------|--------------------------------|-----------------------------------|
# | [*(S)extortion*](https://timesofindia.indiatimes.com/city/ahmedabad/deepfakes-replace-women-on-sextortion-calls/articleshow/86020397.cms)           | Extortion                      | News media manipulation           |
# | Defamation             | [*Identity theft*](https://mashable.com/article/deepfake-job-interviews-fbi)                 | Damage to economic stability      |
# | Intimidation           | [*Fraud (e.g. insurance/payment)*](https://www.forbes.com/sites/thomasbrewster/2021/10/14/huge-bank-fraud-uses-deep-fake-voice-tech-to-steal-millions/) | Damage to justice system          |
# | Bullying               | Stock-price manipulation       | Damage to scientific system       |
# | Undermining trust      | Brand damage                   | Erosion of trust                  |
# |                        | Reputational damage            | Damage to democracy               |
# |                        |                                | Manipulation of elections         |
# |                        |                                | Damage to international relations |
# |                        |                                | [*Damage to national security*](https://www.npr.org/2022/03/16/1087062648/deepfake-video-zelenskyy-experts-war-manipulation-ukraine-russia)       |
#
# In Singapore, [*AI Singapore*](https://aisingapore.org/) launched a five-month long "[*Trusted Media Challenge*](https://www.channelnewsasia.com/singapore/ai-singapore-launches-competition-design-solutions-detecting-fake-media-2017431)" on 15 July 2021 with the Trusted Media Challenge (TMC) dataset for contestants to design solutions that will help detect fake media.
#
# During a presentation at the recently concluded Singapore Defence Technology Summit on 14 Oct 2021, Associate Professor Hao Li, founder of Pinscreen, a start-up that develops photorealistic AI-driven virtual avatars, opined that the most nefarious is how deep fakes could disrupt national security, by spreading misinformation and influencing public opinion ([*Source*](https://www.channelnewsasia.com/singapore/deepfakes-ai-security-threat-face-swapping-2252161)). Assoc Prof Li also taught computer science at the University of Southern California.
#
# In case we think that most of us are literally just ordinary persons who would be unlikely targets of potential deep fakes exploits, the recent case of a Singaporean man's face ending up in deep fake porn on 21 Apr 2022 after he refuses to pay hacker SGD 8,000 hits really close to home! ([*Source*](https://news.yahoo.com/singaporean-mans-face-ends-deepfake-171743924.html))
#
# All these inspired me to apply what I have learnt to establish a functional process workflow and develop a Deep Fake Detector potentially capable of discerning deep fake videos from real ones.
#
# Cognizant of the systemic bias of AI models against underrepresented grouped data, as well as many deep fake detectors being sensitive to skin tones and other face features, I requested with [*AI Singapore*](https://aisingapore.org/) for the TMC Dataset which focuses on Asian content and ethnicities because other datasets usually have a majority of Caucasians. This potentially ensures greater relevance of the AI model developed to the broader Asian region.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Establish a functional process workflow and develop an **AI model** with a **dataset focused on Asian content and ethnicities** that **detects and correctly identifies deep fakes videos (excluding their audio component)** with an **accuracy of at least 80%** as my humble contribution towards the ongoing efforts of the Data Science community, industries, and governments alike, in combating deep fakes exploits and applying Artificial Intelligence (AI) technologies towards serving the greater good of the general public.

# %% [markdown]
# ## Trusted Media Challenge (TMC) Dataset

# %% [markdown]
# **CSV Files**:
# - **_train.csv_**: Initial csv file with new data labels and file sizes included. New data labels and file sizes were not provided by AI Singapore.
# - **_train_data.csv_**: csv file for the TMC dataset of 6,943 real and fake videos with additional information included.
# - **_train_subset.csv_**: csv file for the initial subset of 2,080 real and fake videos from the TMC dataset.
# - **_train_faces_subset.csv_**: csv file for the final subset of 1,560 real and fake videos from the TMC dataset.
# - **_testerTMC.csv_**: csv file for the 12 **NEW** videos that was used in the TMC Sample Test to ascertain the robustness of the trained model.
#
# Data dictionary for **_train.csv_** (last 4 features are not applicable), **_train_data.csv_**, **_train_subset.csv_**, **_train_faces_subset.csv_**, and **_testerTMC.csv_**:
#
# | **Feature**   | **Type** | **Description**                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |---------------|----------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | filename      | string   | Alphanumeric file name of each video file in mp4 format with video resolution of 360p or 1080p                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | srcDataSource | string   | Source video featuring source person from which fake video will be generated.<br>**Professionals**: CNA news presenters and journalists as well as ST interviewees<br>**Amateurs**: Freelancers                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | trgDataSource | string   | Target video featuring target person.<br>**Professionals**: CNA news presenters and journalists as well as ST interviewees<br>**Amateurs**: Freelancers<br>**[ Blank ]**: Real video                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | videoType     | string   | **Type-1**: Fake video and fake audio<br>**Type-2**: Fake video and real audio<br>**Type-3**: Real video and fake audio<br>**Type-4**: Real video and real audio<br>**[ Blank ]**: Real video with audio<br>Refer to points 4 and 5 above for details.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | new_label     | integer  | **0**: Real video<br>**1**: Fake video                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | label         | string   | **a00**: Real video of Amateur<br>**p00**: Real video of Professional<br>**aa1**: Type-1 Fake video from Amateur source and target<br>**aa2**: Type-2 Fake video from Amateur source and target<br>**aa3**: Type-3 Fake video from Amateur source and target<br>**aa4**: Type-4 Fake video from Amateur source and target<br>**ap1**: Type-1 Fake video from Amateur source and Professional target<br>**ap2**: Type-2 Fake video from Amateur source and Professional target<br>**ap3**: Type-3 Fake video from Amateur source and Professional target<br>**ap4**: Type-4 Fake video from Amateur source and Professional target<br>**pp1**: Type-1 Fake video from Professional source and target<br>**pp2**: Type-2 Fake video from Professional source and target<br>**pp3**: Type-3 Fake video from Professional source and target<br>**pp4**: Type-4 Fake video from Professional source and target<br>**pa1**: Type-1 Fake video from Professional source and Amateur target<br>**pa2**: Type-2 Fake video from Professional source and Amateur target<br>**pa3**: Type-3 Fake video from Professional source and Amateur target<br>**pa4**: Type-4 Fake video from Professional source and Amateur target |
# | size          | integer  | File size in kilobyte (KB)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | frame_count   | float    | Number of frames in the video file                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | fps           | float    | Frame rate in frames per second (FPS)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | duration      | float    | Duration of video in seconds (s)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | images        | integer  | Number of still images captured from video (in subsequent preprocessing steps)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# **CSV Files**:
# - **_train.csv_**: Initial csv file with new data labels and file sizes included. New data labels and file sizes were not provided by AI Singapore.
# - **_train_data.csv_**: csv file for the TMC dataset of 6,943 real and fake videos with additional information included.
# - **_train_subset.csv_**: csv file for the initial subset of 2,080 real and fake videos from the TMC dataset.
# - **_train_faces_subset.csv_**: csv file for the final subset of 1,560 real and fake videos from the TMC dataset.
# - **_testerTMC.csv_**: csv file for the 12 **NEW** videos that was used in the TMC Sample Test to ascertain the robustness of the trained model.
#
# Data dictionary for **_train.csv_** (last 4 features are not applicable), **_train_data.csv_**, **_train_subset.csv_**, **_train_faces_subset.csv_**, and **_testerTMC.csv_**:
#
# | **Feature**   | **Type** | **Description**                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |---------------|----------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | filename      | string   | Alphanumeric file name of each video file in mp4 format with video resolution of 360p or 1080p                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | srcDataSource | string   | Source video featuring source person from which fake video will be generated.<br>**Professionals**: CNA news presenters and journalists as well as ST interviewees<br>**Amateurs**: Freelancers                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | trgDataSource | string   | Target video featuring target person.<br>**Professionals**: CNA news presenters and journalists as well as ST interviewees<br>**Amateurs**: Freelancers<br>**[ Blank ]**: Real video                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | videoType     | string   | **Type-1**: Fake video and fake audio<br>**Type-2**: Fake video and real audio<br>**Type-3**: Real video and fake audio<br>**Type-4**: Real video and real audio<br>**[ Blank ]**: Real video with audio<br>Refer to points 4 and 5 above for details.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | new_label     | integer  | **0**: Real video<br>**1**: Fake video                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | label         | string   | **a00**: Real video of Amateur<br>**p00**: Real video of Professional<br>**aa1**: Type-1 Fake video from Amateur source and target<br>**aa2**: Type-2 Fake video from Amateur source and target<br>**aa3**: Type-3 Fake video from Amateur source and target<br>**aa4**: Type-4 Fake video from Amateur source and target<br>**ap1**: Type-1 Fake video from Amateur source and Professional target<br>**ap2**: Type-2 Fake video from Amateur source and Professional target<br>**ap3**: Type-3 Fake video from Amateur source and Professional target<br>**ap4**: Type-4 Fake video from Amateur source and Professional target<br>**pp1**: Type-1 Fake video from Professional source and target<br>**pp2**: Type-2 Fake video from Professional source and target<br>**pp3**: Type-3 Fake video from Professional source and target<br>**pp4**: Type-4 Fake video from Professional source and target<br>**pa1**: Type-1 Fake video from Professional source and Amateur target<br>**pa2**: Type-2 Fake video from Professional source and Amateur target<br>**pa3**: Type-3 Fake video from Professional source and Amateur target<br>**pa4**: Type-4 Fake video from Professional source and Amateur target |
# | size          | integer  | File size in kilobyte (KB)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | frame_count   | float    | Number of frames in the video file                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | fps           | float    | Frame rate in frames per second (FPS)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | duration      | float    | Duration of video in seconds (s)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | images        | integer  | Number of still images captured from video (in subsequent preprocessing steps)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |

# %% [markdown]
# The following are the detailed breakdown of the 2,080 initial and 1,560 final subsets of real and fake videos from the TMC dataset, as well as the 12 **NEW** TMC dataset videos (for the Sample Test), used:
#
#
# | **label** | **srcDataSource** | **trgDataSource** | **videoType** | **new_label** | **Quantity** | **Remarks** | **Initial Subset (2080 Videos)** | **Final Subset (1560 Videos)** | **TMC Sample Test (12 Videos)** |
# |-----------|-------------------|-------------------|---------------|---------------|--------------|-------------|----------------------------------|--------------------------------|---------------------------------|
# | aa1       | amateur           | amateur           | Type-1        | 1             | 65           | FAKE        | ✓                                | ✓                              | 1                               |
# | aa2       | amateur           | amateur           | Type-2        | 1             | 65           | FAKE        | ✓                                | ✓                              | 1                               |
# | aa3       | amateur           | amateur           | Type-3        | 1             | 65           | FAKE        | ✓                                |                                |                                 |
# | aa4       | amateur           | amateur           | Type-4        | 1             | 65           | FAKE        | ✓                                |                                |                                 |
# | ap1       | amateur           | professional      | Type-1        | 1             | 65           | FAKE        | ✓                                | ✓                              | 1                               |
# | ap2       | amateur           | professional      | Type-2        | 1             | 65           | FAKE        | ✓                                | ✓                              | 1                               |
# | ap3       | amateur           | professional      | Type-3        | 1             | 65           | FAKE        | ✓                                |                                |                                 |
# | ap4       | amateur           | professional      | Type-4        | 1             | 65           | FAKE        | ✓                                |                                |                                 |
# | pa1       | professional      | amateur           | Type-1        | 1             | 65           | FAKE        | ✓                                | ✓                              | 1                               |
# | pa2       | professional      | amateur           | Type-2        | 1             | 65           | FAKE        | ✓                                | ✓                              | 1                               |
# | pa3       | professional      | amateur           | Type-3        | 1             | 65           | FAKE        | ✓                                |                                |                                 |
# | pa4       | professional      | amateur           | Type-4        | 1             | 65           | FAKE        | ✓                                |                                |                                 |
# | pp1       | professional      | professional      | Type-1        | 1             | 65           | FAKE        | ✓                                | ✓                              | 1                               |
# | pp2       | professional      | professional      | Type-2        | 1             | 65           | FAKE        | ✓                                | ✓                              | 1                               |
# | pp3       | professional      | professional      | Type-3        | 1             | 65           | FAKE        | ✓                                |                                |                                 |
# | pp4       | professional      | professional      | Type-4        | 1             | 65           | FAKE        | ✓                                |                                |                                 |
# | **a00**   | **amateur**       |                   |               | **0**         | **520**      | **REAL**    | **✓**                            | **✓**                          | **2**                           |
# | **p00**   | **professional**  |                   |               | **0**         | **520**      | **REAL**    | **✓**                            | **✓**                          | **2**                           |
#
# **Notes**:
# - During Train-Test Split, all 520 Type-1 and Type-2 fake videos are selected while another 520 out of the 1040 real videos are randomly selected for use.
# - 12 **NEW** Videos from the same TMC dataset was used in the TMC Sample Test to ascertain the robustness of the trained model. These 12 **NEW** Videos have **never been used** as part of the initial Train, Validation, and Test datasets, and has undergone the same project steps 1, 2 and 5 detailed below before uploading to Google Drive.

# %% [markdown]
# ## Project Scope

# %% [markdown]
# For the purpose of this project, a subset of the Trusted Media Challenge (TMC) dataset released by [*AI Singapore*](https://aisingapore.org/) is used to create a [*Convolutional Neural Network (CNN)*](https://en.wikipedia.org/wiki/Convolutional_neural_network) for potential detection of [*deepfake*](https://en.wikipedia.org/wiki/Deepfake) videos based on the **video component only** (i.e. **Type-1** and **Type-2** fake videos **only**). Detection of Type-3 and Type-4 fake videos is **not** within this project's scope.
#
# ---

# %% [markdown]
# ## Overall Project Workflow

# %% [markdown]
# We will perform the following steps for data preprocessing, [*Exploratory Data Analysis (EDA)*](https://en.wikipedia.org/wiki/Exploratory_data_analysis), model training and assessment:
#
# **Data Preprocessing**
#
# [ Notebook: **A -- Relabel & Convert Each Video To Images** ]
#
# 1. Relabel all 6,943 videos' filenames
# 2. Capture frames from each video in PNG format & scale all images to 1080 pixels
#
# [ Notebook: **B -- Obtain Videos Parameters & Move Video Subset** ]
#
# 3. Obtain additional videos' parameters [**_Optional_**]
#  - frame count
#  - fps
#  - duration (_derived_)
#  - number of images that will be extracted per video (_derived_)
# 4. Move all 2,080 initial subset of videos to new folder [**_Optional_**]
#
# [ Notebook: **C -- Crop Faces With MTCNN** ]
#
# 5. Detect, crop & save faces to subfolder
#
# [ Notebook: **D -- Train-Test Split** ] (_This Notebook_)
#
# 6. Prepare Train, Validation & Test Folders
#  - Upload zipped file of split dataset "**_split_dataset.zip_**" to [*Kaggle*](https://www.kaggle.com/) as private dataset
#
# [ Notebook: **E -- Exploratory Data Analysis (EDA)** ]
#
# 7. Exploratory Data Analysis (EDA)
#  - Compare Mean Real Image & Mean Fake Image
#  - Compare contrast between Mean Images
#  - Compare Standard Deviation Real Image & Standard Deviation Fake Image
#  - Compare contrast between Standard Deviation Images
#
# [ Notebook: **F -- Train Model** ]
#
# 8. Train the chosen CNN classifier model
#  - Mount Google Drive
#  - Install and/or import required libraries / packages
#  - Download and unzip private split dataset from [*Kaggle*](https://www.kaggle.com/)
#  - Set global random seed, directories, batch size, image size
#  - Prepare train, validation and test datasets, including rescaling as appropriate according to choice of CNN classifier model
#  - Apply image augmentations on train dataset
#  - Load CNN classifier model pretrained on [*ImageNet*](https://image-net.org/)
#  - Add additional layers to CNN classifier model as appropriate and compile final model
#  - Set up early stopping, reduce learning rate on plateau, and save best model at checkpoint
#  - Initial training of model
#  - Plot Learning Curves
#  - Recompile model with reduced learning rate
#  - Fine tuning training of model
#  - Plot Combined Learning Curves
#  - Load best model's saved weights values, architecture, training configuration, optimizer and its state
#  - Generate predictions with best model
#  - Generate corresponding Confusion Matrix, Receiver Operating Characteristic (ROC) and Classification Report
#  - Apply Best Model to predict faces extracted from 12 new TMC dataset videos
# 9. Limitations, Future Work, Recommendations, and Conclusion
#
#
# ---

# %% [markdown]
# ### Prepare Train, Validation & Test Folders

# %%
import json
import os
import numpy as np
import pandas as pd
import shutil
import splitfolders
from distutils.dir_util import copy_tree

'''
1. Create 5 new folders:
   A) Faces Subset Folder
   B) Temporary Fake Folder
   B) Temporary Real Folder
   C) Fake Subfolder (in Faces Subset Folder)
   D) Real Subfolder (in Faces Subset Folder)
2. Copy all fake faces to Temporary Fake Folder
3. Copy all real faces to Temporary Real Folder
4. Compare total number of fake faces with total number of real faces
5. Move equal numbers of fake and real faces to the Fake Folder and Real Folder respectively
6. Split the fake and real faces into the Train / Validation / Test folders in the ratio of 8:1:1

'''

# Directories where video & image files are stored
video_dir = '.\\data_subset\\'
dataset_dir = '.\\faces_subset\\'
print('Creating Directory: ' + dataset_dir)
os.makedirs(dataset_dir, exist_ok = True)

# Create Temporary Fake Folder
temp_fake_dir = '.\\temp_fake_faces\\'
print('Creating Directory: ' + temp_fake_dir)
os.makedirs(temp_fake_dir, exist_ok = True)

# Create Temporary Real Folder
temp_real_dir = '.\\temp_real_faces\\'
print('Creating Directory: ' + temp_real_dir)
os.makedirs(temp_real_dir, exist_ok = True)

def get_filename_only(file_dir):
    file_basename = os.path.basename(file_dir)
    filename_only = file_basename.split('.')[0]
    return filename_only

# Import video labels data
train = pd.read_csv('train_faces_subset.csv', usecols = ['filename', 'new_label', 'label'])
train['filename'] = train['label'] + '_' + train['filename']

# Create Fake Folder
fake_dir = os.path.join(dataset_dir, 'fake')
print('Creating Directory: ' + fake_dir)
os.makedirs(fake_dir, exist_ok = True)

# Create Real Folder
real_dir = os.path.join(dataset_dir, 'real')
print('Creating Directory: ' + real_dir)
os.makedirs(real_dir, exist_ok = True)

for filename, new_label in zip(train['filename'], train['new_label']):
    print(filename)
    print(new_label)
    temp_dir = os.path.join(os.path.join(video_dir, get_filename_only(filename)), 'faces')
    print(temp_dir)
    if os.path.exists(temp_dir):
        if new_label == 0:      # REAL    
            print('Copying to :' + temp_real_dir)
            copy_tree(temp_dir, temp_real_dir)
        elif new_label == 1:    # FAKE
            print('Copying to :' + temp_fake_dir)
            copy_tree(temp_dir, temp_fake_dir)
        else:
            print('Ignored ....')            

all_fake_faces = [f for f in os.listdir(temp_fake_dir) if os.path.isfile(os.path.join(temp_fake_dir, f))]
all_real_faces = [f for f in os.listdir(temp_real_dir) if os.path.isfile(os.path.join(temp_real_dir, f))]
fake_percent = round(100 * len(all_fake_faces) / (len(all_fake_faces) + len(all_real_faces)), 2)
real_percent = round(100 * len(all_real_faces) / (len(all_fake_faces) + len(all_real_faces)), 2)
print(f'Total Number of Fake faces: {len(all_fake_faces)} (i.e. {fake_percent}% of all faces)')
print(f'Total Number of Real faces: {len(all_real_faces)} (i.e. {real_percent}% of all faces)')

# Compare Total Number of Fake Faces with Total Number of Real Faces
# If Total Number of Fake Faces > Total Number of Real Faces, Down-Sample Fake Faces to same number as Real Faces 
# by randomly choosing same number of Fake Faces as Real Faces
# If Total Number of Real Faces > Total Number of Fake Faces, Down-Sample Real Faces to same number as Fake Faces 
# by randomly choosing same number of Real Faces as Fake Faces
if len(all_fake_faces) > len(all_real_faces):
    random_faces = np.random.choice(all_fake_faces, len(all_real_faces), replace = False)
    for file_name in random_faces:
        source = os.path.join(temp_fake_dir, file_name)
        target = os.path.join(fake_dir, file_name)
        shutil.move(source, target)
    for file_name in all_real_faces:
        source = os.path.join(temp_real_dir, file_name)
        target = os.path.join(real_dir, file_name)
        shutil.move(source, target)
else:
    random_faces = np.random.choice(all_real_faces, len(all_fake_faces), replace = False)
    for file_name in random_faces:
        source = os.path.join(temp_real_dir, file_name)
        target = os.path.join(real_dir, file_name)
        shutil.move(source, target)
    for file_name in all_fake_faces:
        source = os.path.join(temp_fake_dir, file_name)
        target = os.path.join(fake_dir, file_name)
        shutil.move(source, target)

print('Down-Sampling Done!')

# Split into Train / Validation / Test folders in the ratio of 8:1:1
splitfolders.ratio(dataset_dir, output = 'split_dataset', seed = 1337, ratio = (.8, .1, .1)) # default values
print('Train / Validation / Test Split Done!')
# Out:
# Creating Directory: .\faces_subset\
# Creating Directory: .\temp_fake_faces\
# Creating Directory: .\temp_real_faces\
# Creating Directory: .\faces_subset\real
# Creating Directory: .\faces_subset\fake
# pp1_9149e78016d11aeb.mp4
# 1
# .\data_subset\pp1_9149e78016d11aeb\faces
# Copying to :.\temp_fake_faces\
# pp1_eacc6b7d3bdb8b39.mp4
# 1
# .\data_subset\pp1_eacc6b7d3bdb8b39\faces
# Copying to :.\temp_fake_faces\
# pp1_026646a4eb385e50.mp4
# 1
# .\data_subset\pp1_026646a4eb385e50\faces
# Copying to :.\temp_fake_faces\
# pp1_8d2db652940a8dc8.mp4
# 1
# .\data_subset\pp1_8d2db652940a8dc8\faces
# Copying to :.\temp_fake_faces\
# pp1_baf6dcb6e2196efa.mp4
# 1
# .\data_subset\pp1_baf6dcb6e2196efa\faces
# Copying to :.\temp_fake_faces\
# pp2_2c33dc22e961f0d7.mp4
# 1
# .\data_subset\pp2_2c33dc22e961f0d7\faces
# Copying to :.\temp_fake_faces\
# pp2_e4ed78bc2aa92b40.mp4
# 1
# .\data_subset\pp2_e4ed78bc2aa92b40\faces
# Copying to :.\temp_fake_faces\
# pp2_77fb2d049f234fbd.mp4
# 1
# .\data_subset\pp2_77fb2d049f234fbd\faces
# Copying to :.\temp_fake_faces\
# pp2_5fb85b52c7d4d045.mp4
# 1
# .\data_subset\pp2_5fb85b52c7d4d045\faces
# Copying to :.\temp_fake_faces\
# pp2_c0ed568e0489acd1.mp4
# 1
# .\data_subset\pp2_c0ed568e0489acd1\faces
# Copying to :.\temp_fake_faces\
# pp1_2f84ad790fb663c3.mp4
# 1
# .\data_subset\pp1_2f84ad790fb663c3\faces
# Copying to :.\temp_fake_faces\
# pp1_dddc115f2cfaa114.mp4
# 1
# .\data_subset\pp1_dddc115f2cfaa114\faces
# Copying to :.\temp_fake_faces\
# pp1_dfbe8e9b46aa95f2.mp4
# 1
# .\data_subset\pp1_dfbe8e9b46aa95f2\faces
# Copying to :.\temp_fake_faces\
# pp1_b8397ecd1918d8c7.mp4
# 1
# .\data_subset\pp1_b8397ecd1918d8c7\faces
# Copying to :.\temp_fake_faces\
# pp1_22242961a36560ba.mp4
# 1
# .\data_subset\pp1_22242961a36560ba\faces
# Copying to :.\temp_fake_faces\
# pp1_efe7113fb2ff3225.mp4
# 1
# .\data_subset\pp1_efe7113fb2ff3225\faces
# Copying to :.\temp_fake_faces\
# pp1_7ac279e244bfe17f.mp4
# 1
# .\data_subset\pp1_7ac279e244bfe17f\faces
# Copying to :.\temp_fake_faces\
# pp1_05cfe3a5d0acdaa9.mp4
# 1
# .\data_subset\pp1_05cfe3a5d0acdaa9\faces
# Copying to :.\temp_fake_faces\
# pp1_4c7db532afa41af1.mp4
# 1
# .\data_subset\pp1_4c7db532afa41af1\faces
# Copying to :.\temp_fake_faces\
# pp1_8e4ecd88a1a32974.mp4
# 1
# .\data_subset\pp1_8e4ecd88a1a32974\faces
# Copying to :.\temp_fake_faces\
# pp2_911f7bd7f62e18d6.mp4
# 1
# .\data_subset\pp2_911f7bd7f62e18d6\faces
# Copying to :.\temp_fake_faces\
# pp2_4ce8595720eac4e5.mp4
# 1
# .\data_subset\pp2_4ce8595720eac4e5\faces
# Copying to :.\temp_fake_faces\
# pp2_dc276552da7ef079.mp4
# 1
# .\data_subset\pp2_dc276552da7ef079\faces
# Copying to :.\temp_fake_faces\
# pp2_4c50a2f06eae536b.mp4
# 1
# .\data_subset\pp2_4c50a2f06eae536b\faces
# Copying to :.\temp_fake_faces\
# pp2_ef175aa993c44e5e.mp4
# 1
# .\data_subset\pp2_ef175aa993c44e5e\faces
# Copying to :.\temp_fake_faces\
# pp2_50950e820cd04abf.mp4
# 1
# .\data_subset\pp2_50950e820cd04abf\faces
# Copying to :.\temp_fake_faces\
# pp2_14a98ec3ccf69c9d.mp4
# 1
# .\data_subset\pp2_14a98ec3ccf69c9d\faces
# Copying to :.\temp_fake_faces\
# pp2_45d0d373cc58fb49.mp4
# 1
# .\data_subset\pp2_45d0d373cc58fb49\faces
# Copying to :.\temp_fake_faces\
# pp2_2cd45c3ed3a8eaed.mp4
# 1
# .\data_subset\pp2_2cd45c3ed3a8eaed\faces
# Copying to :.\temp_fake_faces\
# pp2_0b4e28407c222fe2.mp4
# 1
# .\data_subset\pp2_0b4e28407c222fe2\faces
# Copying to :.\temp_fake_faces\
# pp1_c7d85cb8e271057e.mp4
# 1
# .\data_subset\pp1_c7d85cb8e271057e\faces
# Copying to :.\temp_fake_faces\
# pp1_10937aea21ac0351.mp4
# 1
# .\data_subset\pp1_10937aea21ac0351\faces
# Copying to :.\temp_fake_faces\
# pp1_9ba1718adeba64a9.mp4
# 1
# .\data_subset\pp1_9ba1718adeba64a9\faces
# Copying to :.\temp_fake_faces\
# pp1_86258427002a0fb9.mp4
# 1
# .\data_subset\pp1_86258427002a0fb9\faces
# Copying to :.\temp_fake_faces\
# pp1_213503b9f0c67e27.mp4
# 1
# .\data_subset\pp1_213503b9f0c67e27\faces
# Copying to :.\temp_fake_faces\
# pp1_e15df21d9076a1e9.mp4
# 1
# .\data_subset\pp1_e15df21d9076a1e9\faces
# Copying to :.\temp_fake_faces\
# pp1_5dd2c27a2ad7b82e.mp4
# 1
# .\data_subset\pp1_5dd2c27a2ad7b82e\faces
# Copying to :.\temp_fake_faces\
# pp1_67a254e0395ed4dc.mp4
# 1
# .\data_subset\pp1_67a254e0395ed4dc\faces
# Copying to :.\temp_fake_faces\
# pp1_c9df071111d488df.mp4
# 1
# .\data_subset\pp1_c9df071111d488df\faces
# Copying to :.\temp_fake_faces\
# pp1_bb64afc1836d070a.mp4
# 1
# .\data_subset\pp1_bb64afc1836d070a\faces
# Copying to :.\temp_fake_faces\
# pp2_05ac1a2f7435cd7b.mp4
# 1
# .\data_subset\pp2_05ac1a2f7435cd7b\faces
# Copying to :.\temp_fake_faces\
# pp2_e8c3c060408d427d.mp4
# 1
# .\data_subset\pp2_e8c3c060408d427d\faces
# Copying to :.\temp_fake_faces\
# pp2_009d0a399a705fa6.mp4
# 1
# .\data_subset\pp2_009d0a399a705fa6\faces
# Copying to :.\temp_fake_faces\
# pp2_a3efb413db80b546.mp4
# 1
# .\data_subset\pp2_a3efb413db80b546\faces
# Copying to :.\temp_fake_faces\
# pp2_c9e3016c721e0d5d.mp4
# 1
# .\data_subset\pp2_c9e3016c721e0d5d\faces
# Copying to :.\temp_fake_faces\
# pp2_2bc001ee13683ecb.mp4
# 1
# .\data_subset\pp2_2bc001ee13683ecb\faces
# Copying to :.\temp_fake_faces\
# pp2_46f92e4c55f51524.mp4
# 1
# .\data_subset\pp2_46f92e4c55f51524\faces
# Copying to :.\temp_fake_faces\
# pp2_3be0e0107a71f489.mp4
# 1
# .\data_subset\pp2_3be0e0107a71f489\faces
# Copying to :.\temp_fake_faces\
# pp2_b9505f027ce090fd.mp4
# 1
# .\data_subset\pp2_b9505f027ce090fd\faces
# Copying to :.\temp_fake_faces\
# pp2_35391a408825ad90.mp4
# 1
# .\data_subset\pp2_35391a408825ad90\faces
# Copying to :.\temp_fake_faces\
# pp1_5df873ae1079e384.mp4
# 1
# .\data_subset\pp1_5df873ae1079e384\faces
# Copying to :.\temp_fake_faces\
# pp1_0682763ea0f5070c.mp4
# 1
# .\data_subset\pp1_0682763ea0f5070c\faces
# Copying to :.\temp_fake_faces\
# pp1_f06e4a04ea595c1d.mp4
# 1
# .\data_subset\pp1_f06e4a04ea595c1d\faces
# Copying to :.\temp_fake_faces\
# pp1_719f82357ff14ec5.mp4
# 1
# .\data_subset\pp1_719f82357ff14ec5\faces
# Copying to :.\temp_fake_faces\
# pp1_1f139142525f0a71.mp4
# 1
# .\data_subset\pp1_1f139142525f0a71\faces
# Copying to :.\temp_fake_faces\
# pp2_faa3d37eaef34841.mp4
# 1
# .\data_subset\pp2_faa3d37eaef34841\faces
# Copying to :.\temp_fake_faces\
# pp2_4b946feed840909e.mp4
# 1
# .\data_subset\pp2_4b946feed840909e\faces
# Copying to :.\temp_fake_faces\
# pp2_76271d1e8c340515.mp4
# 1
# .\data_subset\pp2_76271d1e8c340515\faces
# Copying to :.\temp_fake_faces\
# pp2_dd47c70614c2f618.mp4
# 1
# .\data_subset\pp2_dd47c70614c2f618\faces
# Copying to :.\temp_fake_faces\
# pp2_4038e46376ec0b7a.mp4
# 1
# .\data_subset\pp2_4038e46376ec0b7a\faces
# Copying to :.\temp_fake_faces\
# pp2_56daf021a4f685e1.mp4
# 1
# .\data_subset\pp2_56daf021a4f685e1\faces
# Copying to :.\temp_fake_faces\
# pp2_ea0af20e5d582e75.mp4
# 1
# .\data_subset\pp2_ea0af20e5d582e75\faces
# Copying to :.\temp_fake_faces\
# pp2_3c3ffa46e30ec759.mp4
# 1
# .\data_subset\pp2_3c3ffa46e30ec759\faces
# Copying to :.\temp_fake_faces\
# pp2_027b0fae2e805dd3.mp4
# 1
# .\data_subset\pp2_027b0fae2e805dd3\faces
# Copying to :.\temp_fake_faces\
# pp2_5fd07a2fb8d65ed4.mp4
# 1
# .\data_subset\pp2_5fd07a2fb8d65ed4\faces
# Copying to :.\temp_fake_faces\
# pp1_3c724b3c0c11e884.mp4
# 1
# .\data_subset\pp1_3c724b3c0c11e884\faces
# Copying to :.\temp_fake_faces\
# pp1_d424361e31807cea.mp4
# 1
# .\data_subset\pp1_d424361e31807cea\faces
# Copying to :.\temp_fake_faces\
# pp1_f736779001e4a3d3.mp4
# 1
# .\data_subset\pp1_f736779001e4a3d3\faces
# Copying to :.\temp_fake_faces\
# pp1_ea6dcdeaf7179411.mp4
# 1
# .\data_subset\pp1_ea6dcdeaf7179411\faces
# Copying to :.\temp_fake_faces\
# pp1_cbf9ac237959f480.mp4
# 1
# .\data_subset\pp1_cbf9ac237959f480\faces
# Copying to :.\temp_fake_faces\
# pp1_869836ce91f40ece.mp4
# 1
# .\data_subset\pp1_869836ce91f40ece\faces
# Copying to :.\temp_fake_faces\
# pp1_0a3e16d70c766db6.mp4
# 1
# .\data_subset\pp1_0a3e16d70c766db6\faces
# Copying to :.\temp_fake_faces\
# pp1_9718e138d2955dd8.mp4
# 1
# .\data_subset\pp1_9718e138d2955dd8\faces
# Copying to :.\temp_fake_faces\
# pp1_bfc77e9ac975637c.mp4
# 1
# .\data_subset\pp1_bfc77e9ac975637c\faces
# Copying to :.\temp_fake_faces\
# pp1_602c6dae3f090ced.mp4
# 1
# .\data_subset\pp1_602c6dae3f090ced\faces
# Copying to :.\temp_fake_faces\
# pp1_aa7ac9a068037df7.mp4
# 1
# .\data_subset\pp1_aa7ac9a068037df7\faces
# Copying to :.\temp_fake_faces\
# pp1_dd6ea9b5de3c4fc7.mp4
# 1
# .\data_subset\pp1_dd6ea9b5de3c4fc7\faces
# Copying to :.\temp_fake_faces\
# pp1_912e7d3567aad236.mp4
# 1
# .\data_subset\pp1_912e7d3567aad236\faces
# Copying to :.\temp_fake_faces\
# pp1_f45978fcfd91f408.mp4
# 1
# .\data_subset\pp1_f45978fcfd91f408\faces
# Copying to :.\temp_fake_faces\
# pp1_134aadb29f64749c.mp4
# 1
# .\data_subset\pp1_134aadb29f64749c\faces
# Copying to :.\temp_fake_faces\
# pp1_de6e70cb738f95d7.mp4
# 1
# .\data_subset\pp1_de6e70cb738f95d7\faces
# Copying to :.\temp_fake_faces\
# pp1_bd7921b4e776f7e9.mp4
# 1
# .\data_subset\pp1_bd7921b4e776f7e9\faces
# Copying to :.\temp_fake_faces\
# pp1_ab56e7569516c8ff.mp4
# 1
# .\data_subset\pp1_ab56e7569516c8ff\faces
# Copying to :.\temp_fake_faces\
# pp1_8e9e188fcc99599c.mp4
# 1
# .\data_subset\pp1_8e9e188fcc99599c\faces
# Copying to :.\temp_fake_faces\
# pp1_4d77e8cb5d445928.mp4
# 1
# .\data_subset\pp1_4d77e8cb5d445928\faces
# Copying to :.\temp_fake_faces\
# pp2_bb93bc2f12f1a0d3.mp4
# 1
# .\data_subset\pp2_bb93bc2f12f1a0d3\faces
# Copying to :.\temp_fake_faces\
# pp2_abdb86bfd220af53.mp4
# 1
# .\data_subset\pp2_abdb86bfd220af53\faces
# Copying to :.\temp_fake_faces\
# pp2_d2361040fdc4d1bb.mp4
# 1
# .\data_subset\pp2_d2361040fdc4d1bb\faces
# Copying to :.\temp_fake_faces\
# pp2_905df65901946488.mp4
# 1
# .\data_subset\pp2_905df65901946488\faces
# Copying to :.\temp_fake_faces\
# pp2_aa9aebff16c7ca56.mp4
# 1
# .\data_subset\pp2_aa9aebff16c7ca56\faces
# Copying to :.\temp_fake_faces\
# pp2_7102b1b25a49c981.mp4
# 1
# .\data_subset\pp2_7102b1b25a49c981\faces
# Copying to :.\temp_fake_faces\
# pp2_26b43e284bd3573a.mp4
# 1
# .\data_subset\pp2_26b43e284bd3573a\faces
# Copying to :.\temp_fake_faces\
# pp2_2f3bc73a39ef7636.mp4
# 1
# .\data_subset\pp2_2f3bc73a39ef7636\faces
# Copying to :.\temp_fake_faces\
# pp2_9d23c66137ad885e.mp4
# 1
# .\data_subset\pp2_9d23c66137ad885e\faces
# Copying to :.\temp_fake_faces\
# pp2_c0f8617867722b56.mp4
# 1
# .\data_subset\pp2_c0f8617867722b56\faces
# Copying to :.\temp_fake_faces\
# pp1_996338274e4ae419.mp4
# 1
# .\data_subset\pp1_996338274e4ae419\faces
# Copying to :.\temp_fake_faces\
# pp1_dab3d9a49ee67a64.mp4
# 1
# .\data_subset\pp1_dab3d9a49ee67a64\faces
# Copying to :.\temp_fake_faces\
# pp1_80f3c0e04ddac695.mp4
# 1
# .\data_subset\pp1_80f3c0e04ddac695\faces
# Copying to :.\temp_fake_faces\
# pp1_a202b08993034dad.mp4
# 1
# .\data_subset\pp1_a202b08993034dad\faces
# Copying to :.\temp_fake_faces\
# pp1_9d19737533c7a55f.mp4
# 1
# .\data_subset\pp1_9d19737533c7a55f\faces
# Copying to :.\temp_fake_faces\
# pp1_6fc1e3a102772331.mp4
# 1
# .\data_subset\pp1_6fc1e3a102772331\faces
# Copying to :.\temp_fake_faces\
# pp1_6a69963fde2e8591.mp4
# 1
# .\data_subset\pp1_6a69963fde2e8591\faces
# Copying to :.\temp_fake_faces\
# pp1_1e6fd670c60b295e.mp4
# 1
# .\data_subset\pp1_1e6fd670c60b295e\faces
# Copying to :.\temp_fake_faces\
# pp1_e400c95641617804.mp4
# 1
# .\data_subset\pp1_e400c95641617804\faces
# Copying to :.\temp_fake_faces\
# pp1_ce870d888b19c721.mp4
# 1
# .\data_subset\pp1_ce870d888b19c721\faces
# Copying to :.\temp_fake_faces\
# pp2_141c277e84cedcd0.mp4
# 1
# .\data_subset\pp2_141c277e84cedcd0\faces
# Copying to :.\temp_fake_faces\
# pp2_711ad3a1f5a7d60f.mp4
# 1
# .\data_subset\pp2_711ad3a1f5a7d60f\faces
# Copying to :.\temp_fake_faces\
# pp2_1bc298e32c743b5d.mp4
# 1
# .\data_subset\pp2_1bc298e32c743b5d\faces
# Copying to :.\temp_fake_faces\
# pp2_439faab43e053213.mp4
# 1
# .\data_subset\pp2_439faab43e053213\faces
# Copying to :.\temp_fake_faces\
# pp2_a66b6bc46ef62d9b.mp4
# 1
# .\data_subset\pp2_a66b6bc46ef62d9b\faces
# Copying to :.\temp_fake_faces\
# pp2_ce2795ac3dd36d44.mp4
# 1
# .\data_subset\pp2_ce2795ac3dd36d44\faces
# Copying to :.\temp_fake_faces\
# pp2_3986ed71e4cf3d97.mp4
# 1
# .\data_subset\pp2_3986ed71e4cf3d97\faces
# Copying to :.\temp_fake_faces\
# pp2_f58d131a0f68f794.mp4
# 1
# .\data_subset\pp2_f58d131a0f68f794\faces
# Copying to :.\temp_fake_faces\
# pp2_31fc61adb1d9cc8a.mp4
# 1
# .\data_subset\pp2_31fc61adb1d9cc8a\faces
# Copying to :.\temp_fake_faces\
# pp2_161e737eb6cbedf5.mp4
# 1
# .\data_subset\pp2_161e737eb6cbedf5\faces
# Copying to :.\temp_fake_faces\
# pp2_4572592747214661.mp4
# 1
# .\data_subset\pp2_4572592747214661\faces
# Copying to :.\temp_fake_faces\
# pp2_883950eb247bf1f2.mp4
# 1
# .\data_subset\pp2_883950eb247bf1f2\faces
# Copying to :.\temp_fake_faces\
# pp2_568e5d5ef30e7182.mp4
# 1
# .\data_subset\pp2_568e5d5ef30e7182\faces
# Copying to :.\temp_fake_faces\
# pp2_aa3e0959684949fb.mp4
# 1
# .\data_subset\pp2_aa3e0959684949fb\faces
# Copying to :.\temp_fake_faces\
# pp2_0bc556162b02f106.mp4
# 1
# .\data_subset\pp2_0bc556162b02f106\faces
# Copying to :.\temp_fake_faces\
# pp1_757c138baab84c0c.mp4
# 1
# .\data_subset\pp1_757c138baab84c0c\faces
# Copying to :.\temp_fake_faces\
# pp1_80341c5ada3ed577.mp4
# 1
# .\data_subset\pp1_80341c5ada3ed577\faces
# Copying to :.\temp_fake_faces\
# pp1_a219f0289aea9e59.mp4
# 1
# .\data_subset\pp1_a219f0289aea9e59\faces
# Copying to :.\temp_fake_faces\
# pp1_6ed7a38cf532de76.mp4
# 1
# .\data_subset\pp1_6ed7a38cf532de76\faces
# Copying to :.\temp_fake_faces\
# pp1_1aa92d8478a55b64.mp4
# 1
# .\data_subset\pp1_1aa92d8478a55b64\faces
# Copying to :.\temp_fake_faces\
# pp2_50e5fe2d26ee1965.mp4
# 1
# .\data_subset\pp2_50e5fe2d26ee1965\faces
# Copying to :.\temp_fake_faces\
# pp2_72c7d119ebfe4dbc.mp4
# 1
# .\data_subset\pp2_72c7d119ebfe4dbc\faces
# Copying to :.\temp_fake_faces\
# pp2_f5e8df58b1e838ba.mp4
# 1
# .\data_subset\pp2_f5e8df58b1e838ba\faces
# Copying to :.\temp_fake_faces\
# pp2_0651da76d22478a0.mp4
# 1
# .\data_subset\pp2_0651da76d22478a0\faces
# Copying to :.\temp_fake_faces\
# pp2_a4ee1a80a73a3416.mp4
# 1
# .\data_subset\pp2_a4ee1a80a73a3416\faces
# Copying to :.\temp_fake_faces\
# ap1_586b7657c91f5df9.mp4
# 1
# .\data_subset\ap1_586b7657c91f5df9\faces
# Copying to :.\temp_fake_faces\
# ap2_e3ed57fa951fe1e9.mp4
# 1
# .\data_subset\ap2_e3ed57fa951fe1e9\faces
# Copying to :.\temp_fake_faces\
# ap2_6eaa24846398494d.mp4
# 1
# .\data_subset\ap2_6eaa24846398494d\faces
# Copying to :.\temp_fake_faces\
# pa2_b88549ba2f83975d.mp4
# 1
# .\data_subset\pa2_b88549ba2f83975d\faces
# Copying to :.\temp_fake_faces\
# pa1_7069015f3fe7f384.mp4
# 1
# .\data_subset\pa1_7069015f3fe7f384\faces
# Copying to :.\temp_fake_faces\
# pa2_fc6d4f68025e46a1.mp4
# 1
# .\data_subset\pa2_fc6d4f68025e46a1\faces
# Copying to :.\temp_fake_faces\
# pa2_1489058e27467f93.mp4
# 1
# .\data_subset\pa2_1489058e27467f93\faces
# Copying to :.\temp_fake_faces\
# ap1_176f7e6e49b9aab9.mp4
# 1
# .\data_subset\ap1_176f7e6e49b9aab9\faces
# Copying to :.\temp_fake_faces\
# ap1_dd25594348d4b4e5.mp4
# 1
# .\data_subset\ap1_dd25594348d4b4e5\faces
# Copying to :.\temp_fake_faces\
# aa2_8185282e4919f7eb.mp4
# 1
# .\data_subset\aa2_8185282e4919f7eb\faces
# Copying to :.\temp_fake_faces\
# aa1_ce4675bcdad0ad07.mp4
# 1
# .\data_subset\aa1_ce4675bcdad0ad07\faces
# Copying to :.\temp_fake_faces\
# aa1_d7335e2242b385fd.mp4
# 1
# .\data_subset\aa1_d7335e2242b385fd\faces
# Copying to :.\temp_fake_faces\
# aa1_ba21731b5be4a37f.mp4
# 1
# .\data_subset\aa1_ba21731b5be4a37f\faces
# Copying to :.\temp_fake_faces\
# aa2_e1bca4a02cdebd83.mp4
# 1
# .\data_subset\aa2_e1bca4a02cdebd83\faces
# Copying to :.\temp_fake_faces\
# aa1_f5053ab2528aed1c.mp4
# 1
# .\data_subset\aa1_f5053ab2528aed1c\faces
# Copying to :.\temp_fake_faces\
# ap1_a8b1972ed41735c7.mp4
# 1
# .\data_subset\ap1_a8b1972ed41735c7\faces
# Copying to :.\temp_fake_faces\
# ap1_9ea90ca2d5431684.mp4
# 1
# .\data_subset\ap1_9ea90ca2d5431684\faces
# Copying to :.\temp_fake_faces\
# pa1_95ce2551d76c0dce.mp4
# 1
# .\data_subset\pa1_95ce2551d76c0dce\faces
# Copying to :.\temp_fake_faces\
# ap1_98560a2afc20a623.mp4
# 1
# .\data_subset\ap1_98560a2afc20a623\faces
# Copying to :.\temp_fake_faces\
# pa2_4c5b05fb7905c919.mp4
# 1
# .\data_subset\pa2_4c5b05fb7905c919\faces
# Copying to :.\temp_fake_faces\
# pa2_3fd761860d0bd2be.mp4
# 1
# .\data_subset\pa2_3fd761860d0bd2be\faces
# Copying to :.\temp_fake_faces\
# ap1_784565c8ed241388.mp4
# 1
# .\data_subset\ap1_784565c8ed241388\faces
# Copying to :.\temp_fake_faces\
# ap2_8f15dc5068447fce.mp4
# 1
# .\data_subset\ap2_8f15dc5068447fce\faces
# Copying to :.\temp_fake_faces\
# aa1_5994a441cbba5513.mp4
# 1
# .\data_subset\aa1_5994a441cbba5513\faces
# Copying to :.\temp_fake_faces\
# ap2_5f25915ecfeff112.mp4
# 1
# .\data_subset\ap2_5f25915ecfeff112\faces
# Copying to :.\temp_fake_faces\
# ap1_300d2db70c712c7b.mp4
# 1
# .\data_subset\ap1_300d2db70c712c7b\faces
# Copying to :.\temp_fake_faces\
# ap1_d58a0ecd216e1927.mp4
# 1
# .\data_subset\ap1_d58a0ecd216e1927\faces
# Copying to :.\temp_fake_faces\
# ap1_e5de8e39b54aa580.mp4
# 1
# .\data_subset\ap1_e5de8e39b54aa580\faces
# Copying to :.\temp_fake_faces\
# aa2_854d89efecafd26f.mp4
# 1
# .\data_subset\aa2_854d89efecafd26f\faces
# Copying to :.\temp_fake_faces\
# aa2_796cf7a93f0929a5.mp4
# 1
# .\data_subset\aa2_796cf7a93f0929a5\faces
# Copying to :.\temp_fake_faces\
# aa1_1349c8829d197334.mp4
# 1
# .\data_subset\aa1_1349c8829d197334\faces
# Copying to :.\temp_fake_faces\
# aa2_68b7f7f8bcae2fb2.mp4
# 1
# .\data_subset\aa2_68b7f7f8bcae2fb2\faces
# Copying to :.\temp_fake_faces\
# aa1_ef4bc35e0046486a.mp4
# 1
# .\data_subset\aa1_ef4bc35e0046486a\faces
# Copying to :.\temp_fake_faces\
# aa1_bf41333f77fc6342.mp4
# 1
# .\data_subset\aa1_bf41333f77fc6342\faces
# Copying to :.\temp_fake_faces\
# aa1_07a892c59a432ff1.mp4
# 1
# .\data_subset\aa1_07a892c59a432ff1\faces
# Copying to :.\temp_fake_faces\
# aa2_d03a707d5a9bc463.mp4
# 1
# .\data_subset\aa2_d03a707d5a9bc463\faces
# Copying to :.\temp_fake_faces\
# aa2_e41eefd0077574f9.mp4
# 1
# .\data_subset\aa2_e41eefd0077574f9\faces
# Copying to :.\temp_fake_faces\
# pa1_172d0517fad0f07b.mp4
# 1
# .\data_subset\pa1_172d0517fad0f07b\faces
# Copying to :.\temp_fake_faces\
# pa1_996b26e5ce414042.mp4
# 1
# .\data_subset\pa1_996b26e5ce414042\faces
# Copying to :.\temp_fake_faces\
# ap2_3c81dd426d17f529.mp4
# 1
# .\data_subset\ap2_3c81dd426d17f529\faces
# Copying to :.\temp_fake_faces\
# aa1_2ca37405107109e4.mp4
# 1
# .\data_subset\aa1_2ca37405107109e4\faces
# Copying to :.\temp_fake_faces\
# aa2_95f50dd9afc5542e.mp4
# 1
# .\data_subset\aa2_95f50dd9afc5542e\faces
# Copying to :.\temp_fake_faces\
# ap2_092f8a381275a696.mp4
# 1
# .\data_subset\ap2_092f8a381275a696\faces
# Copying to :.\temp_fake_faces\
# pa1_8848122dd5cefd5c.mp4
# 1
# .\data_subset\pa1_8848122dd5cefd5c\faces
# Copying to :.\temp_fake_faces\
# aa1_7601345c98c79054.mp4
# 1
# .\data_subset\aa1_7601345c98c79054\faces
# Copying to :.\temp_fake_faces\
# pa1_66bd536ae185a4fe.mp4
# 1
# .\data_subset\pa1_66bd536ae185a4fe\faces
# Copying to :.\temp_fake_faces\
# pa2_5d0ee2f1c3ec34c2.mp4
# 1
# .\data_subset\pa2_5d0ee2f1c3ec34c2\faces
# Copying to :.\temp_fake_faces\
# ap1_64f028adb86b1bfe.mp4
# 1
# .\data_subset\ap1_64f028adb86b1bfe\faces
# Copying to :.\temp_fake_faces\
# pa1_d0a30384674a4d3e.mp4
# 1
# .\data_subset\pa1_d0a30384674a4d3e\faces
# Copying to :.\temp_fake_faces\
# pa1_1ab2a4433ea3e43a.mp4
# 1
# .\data_subset\pa1_1ab2a4433ea3e43a\faces
# Copying to :.\temp_fake_faces\
# pa2_e119c7f391a9d282.mp4
# 1
# .\data_subset\pa2_e119c7f391a9d282\faces
# Copying to :.\temp_fake_faces\
# aa1_c4f4eddb92432206.mp4
# 1
# .\data_subset\aa1_c4f4eddb92432206\faces
# Copying to :.\temp_fake_faces\
# ap2_e0a96879d692e91f.mp4
# 1
# .\data_subset\ap2_e0a96879d692e91f\faces
# Copying to :.\temp_fake_faces\
# ap1_a799a041765fe70f.mp4
# 1
# .\data_subset\ap1_a799a041765fe70f\faces
# Copying to :.\temp_fake_faces\
# ap1_3dfd5fc27a9b5a43.mp4
# 1
# .\data_subset\ap1_3dfd5fc27a9b5a43\faces
# Copying to :.\temp_fake_faces\
# pa1_501cb9dc698bcc7f.mp4
# 1
# .\data_subset\pa1_501cb9dc698bcc7f\faces
# Copying to :.\temp_fake_faces\
# pa2_41c0b6b705cd32ef.mp4
# 1
# .\data_subset\pa2_41c0b6b705cd32ef\faces
# Copying to :.\temp_fake_faces\
# aa1_2c597cb866141678.mp4
# 1
# .\data_subset\aa1_2c597cb866141678\faces
# Copying to :.\temp_fake_faces\
# pa1_8972703e311cfcf1.mp4
# 1
# .\data_subset\pa1_8972703e311cfcf1\faces
# Copying to :.\temp_fake_faces\
# aa2_ba9f1a8a2d650ca9.mp4
# 1
# .\data_subset\aa2_ba9f1a8a2d650ca9\faces
# Copying to :.\temp_fake_faces\
# pa2_9f0c4da0f9cb4b44.mp4
# 1
# .\data_subset\pa2_9f0c4da0f9cb4b44\faces
# Copying to :.\temp_fake_faces\
# ap2_a34f2301550615f2.mp4
# 1
# .\data_subset\ap2_a34f2301550615f2\faces
# Copying to :.\temp_fake_faces\
# pa1_2e25109009f5e8b2.mp4
# 1
# .\data_subset\pa1_2e25109009f5e8b2\faces
# Copying to :.\temp_fake_faces\
# ap1_ae6a03e555f7ce9a.mp4
# 1
# .\data_subset\ap1_ae6a03e555f7ce9a\faces
# Copying to :.\temp_fake_faces\
# pa2_c3cee097570952db.mp4
# 1
# .\data_subset\pa2_c3cee097570952db\faces
# Copying to :.\temp_fake_faces\
# pa1_dc63a19dd9ad56a2.mp4
# 1
# .\data_subset\pa1_dc63a19dd9ad56a2\faces
# Copying to :.\temp_fake_faces\
# aa2_c3d82059cc5bf2f5.mp4
# 1
# .\data_subset\aa2_c3d82059cc5bf2f5\faces
# Copying to :.\temp_fake_faces\
# ap2_2816bf6d7dea6a31.mp4
# 1
# .\data_subset\ap2_2816bf6d7dea6a31\faces
# Copying to :.\temp_fake_faces\
# pa1_e953f29958efaa90.mp4
# 1
# .\data_subset\pa1_e953f29958efaa90\faces
# Copying to :.\temp_fake_faces\
# ap1_0e2b57609d1e570c.mp4
# 1
# .\data_subset\ap1_0e2b57609d1e570c\faces
# Copying to :.\temp_fake_faces\
# pa2_b4aecf07f155479f.mp4
# 1
# .\data_subset\pa2_b4aecf07f155479f\faces
# Copying to :.\temp_fake_faces\
# pa2_c78e523376a23456.mp4
# 1
# .\data_subset\pa2_c78e523376a23456\faces
# Copying to :.\temp_fake_faces\
# pa2_418cc08670549ce4.mp4
# 1
# .\data_subset\pa2_418cc08670549ce4\faces
# Copying to :.\temp_fake_faces\
# ap2_3ed1b0b8dc45804b.mp4
# 1
# .\data_subset\ap2_3ed1b0b8dc45804b\faces
# Copying to :.\temp_fake_faces\
# ap2_85165a0561b2e17a.mp4
# 1
# .\data_subset\ap2_85165a0561b2e17a\faces
# Copying to :.\temp_fake_faces\
# aa1_aa2021744307611a.mp4
# 1
# .\data_subset\aa1_aa2021744307611a\faces
# Copying to :.\temp_fake_faces\
# pa1_81e5c88749663254.mp4
# 1
# .\data_subset\pa1_81e5c88749663254\faces
# Copying to :.\temp_fake_faces\
# aa1_29059a8f43dfd041.mp4
# 1
# .\data_subset\aa1_29059a8f43dfd041\faces
# Copying to :.\temp_fake_faces\
# aa2_12b73d44d4b6ff39.mp4
# 1
# .\data_subset\aa2_12b73d44d4b6ff39\faces
# Copying to :.\temp_fake_faces\
# aa1_16367045aa80abae.mp4
# 1
# .\data_subset\aa1_16367045aa80abae\faces
# Copying to :.\temp_fake_faces\
# ap2_1b125cd224d0ab64.mp4
# 1
# .\data_subset\ap2_1b125cd224d0ab64\faces
# Copying to :.\temp_fake_faces\
# aa1_bca768aa4b8bc661.mp4
# 1
# .\data_subset\aa1_bca768aa4b8bc661\faces
# Copying to :.\temp_fake_faces\
# aa2_93a9de4b7dd422f5.mp4
# 1
# .\data_subset\aa2_93a9de4b7dd422f5\faces
# Copying to :.\temp_fake_faces\
# aa1_f66ebbdaa12d90de.mp4
# 1
# .\data_subset\aa1_f66ebbdaa12d90de\faces
# Copying to :.\temp_fake_faces\
# ap2_82bcaa73ae631396.mp4
# 1
# .\data_subset\ap2_82bcaa73ae631396\faces
# Copying to :.\temp_fake_faces\
# ap2_4b53f2b433827d48.mp4
# 1
# .\data_subset\ap2_4b53f2b433827d48\faces
# Copying to :.\temp_fake_faces\
# pa1_ea7b10f4e897ec6e.mp4
# 1
# .\data_subset\pa1_ea7b10f4e897ec6e\faces
# Copying to :.\temp_fake_faces\
# aa2_0f82ffad143a53cc.mp4
# 1
# .\data_subset\aa2_0f82ffad143a53cc\faces
# Copying to :.\temp_fake_faces\
# aa2_f74cbb2f23639a32.mp4
# 1
# .\data_subset\aa2_f74cbb2f23639a32\faces
# Copying to :.\temp_fake_faces\
# ap1_ff63c08d4276aced.mp4
# 1
# .\data_subset\ap1_ff63c08d4276aced\faces
# Copying to :.\temp_fake_faces\
# ap1_ea917bcd14678b31.mp4
# 1
# .\data_subset\ap1_ea917bcd14678b31\faces
# Copying to :.\temp_fake_faces\
# ap1_1e6f004888a3d46f.mp4
# 1
# .\data_subset\ap1_1e6f004888a3d46f\faces
# Copying to :.\temp_fake_faces\
# ap1_f8dbbba555af585e.mp4
# 1
# .\data_subset\ap1_f8dbbba555af585e\faces
# Copying to :.\temp_fake_faces\
# ap2_b8e3b130c17ab304.mp4
# 1
# .\data_subset\ap2_b8e3b130c17ab304\faces
# Copying to :.\temp_fake_faces\
# ap2_7acee6e166c2bf32.mp4
# 1
# .\data_subset\ap2_7acee6e166c2bf32\faces
# Copying to :.\temp_fake_faces\
# ap2_c32961b2fd0f6049.mp4
# 1
# .\data_subset\ap2_c32961b2fd0f6049\faces
# Copying to :.\temp_fake_faces\
# ap2_e11af4f006c5bac9.mp4
# 1
# .\data_subset\ap2_e11af4f006c5bac9\faces
# Copying to :.\temp_fake_faces\
# ap2_33d358e281457f4d.mp4
# 1
# .\data_subset\ap2_33d358e281457f4d\faces
# Copying to :.\temp_fake_faces\
# ap2_61ba23efc5776bf5.mp4
# 1
# .\data_subset\ap2_61ba23efc5776bf5\faces
# Copying to :.\temp_fake_faces\
# ap2_7a10cf71aa6543b3.mp4
# 1
# .\data_subset\ap2_7a10cf71aa6543b3\faces
# Copying to :.\temp_fake_faces\
# ap2_fc238b4e24dc6864.mp4
# 1
# .\data_subset\ap2_fc238b4e24dc6864\faces
# Copying to :.\temp_fake_faces\
# pa2_b676bc916b4fced4.mp4
# 1
# .\data_subset\pa2_b676bc916b4fced4\faces
# Copying to :.\temp_fake_faces\
# pa2_f601477cf160b014.mp4
# 1
# .\data_subset\pa2_f601477cf160b014\faces
# Copying to :.\temp_fake_faces\
# pa2_d20c20aa891550b7.mp4
# 1
# .\data_subset\pa2_d20c20aa891550b7\faces
# Copying to :.\temp_fake_faces\
# pa2_2dcd0f9cedddb42f.mp4
# 1
# .\data_subset\pa2_2dcd0f9cedddb42f\faces
# Copying to :.\temp_fake_faces\
# pa1_030a8299fd9d0869.mp4
# 1
# .\data_subset\pa1_030a8299fd9d0869\faces
# Copying to :.\temp_fake_faces\
# pa1_7f5c6767389eab25.mp4
# 1
# .\data_subset\pa1_7f5c6767389eab25\faces
# Copying to :.\temp_fake_faces\
# pa1_04f3463956e1d1b9.mp4
# 1
# .\data_subset\pa1_04f3463956e1d1b9\faces
# Copying to :.\temp_fake_faces\
# pa1_dced7f170b651f0b.mp4
# 1
# .\data_subset\pa1_dced7f170b651f0b\faces
# Copying to :.\temp_fake_faces\
# pa2_efddb99a3f9361b9.mp4
# 1
# .\data_subset\pa2_efddb99a3f9361b9\faces
# Copying to :.\temp_fake_faces\
# pa2_e0c2a6aa6e84bdcb.mp4
# 1
# .\data_subset\pa2_e0c2a6aa6e84bdcb\faces
# Copying to :.\temp_fake_faces\
# pa2_1734c7c8a46eb3b4.mp4
# 1
# .\data_subset\pa2_1734c7c8a46eb3b4\faces
# Copying to :.\temp_fake_faces\
# pa2_703998cb2576e305.mp4
# 1
# .\data_subset\pa2_703998cb2576e305\faces
# Copying to :.\temp_fake_faces\
# pa2_31aaf7338570262c.mp4
# 1
# .\data_subset\pa2_31aaf7338570262c\faces
# Copying to :.\temp_fake_faces\
# pa2_ef9e982343dc21ff.mp4
# 1
# .\data_subset\pa2_ef9e982343dc21ff\faces
# Copying to :.\temp_fake_faces\
# pa2_4f51db8e04764f32.mp4
# 1
# .\data_subset\pa2_4f51db8e04764f32\faces
# Copying to :.\temp_fake_faces\
# pa2_b1e9c9243590d08a.mp4
# 1
# .\data_subset\pa2_b1e9c9243590d08a\faces
# Copying to :.\temp_fake_faces\
# ap1_dc5f96bea997148b.mp4
# 1
# .\data_subset\ap1_dc5f96bea997148b\faces
# Copying to :.\temp_fake_faces\
# ap1_7be3a7b36ebaa9d1.mp4
# 1
# .\data_subset\ap1_7be3a7b36ebaa9d1\faces
# Copying to :.\temp_fake_faces\
# ap1_2bbcebd0ac2f3cae.mp4
# 1
# .\data_subset\ap1_2bbcebd0ac2f3cae\faces
# Copying to :.\temp_fake_faces\
# ap1_dd8ced7f68e5e26d.mp4
# 1
# .\data_subset\ap1_dd8ced7f68e5e26d\faces
# Copying to :.\temp_fake_faces\
# ap1_75d058c040797871.mp4
# 1
# .\data_subset\ap1_75d058c040797871\faces
# Copying to :.\temp_fake_faces\
# ap1_a9ab42d3a8070da3.mp4
# 1
# .\data_subset\ap1_a9ab42d3a8070da3\faces
# Copying to :.\temp_fake_faces\
# ap1_b4e08d3a49197bff.mp4
# 1
# .\data_subset\ap1_b4e08d3a49197bff\faces
# Copying to :.\temp_fake_faces\
# ap1_a75de2a6adfa9b24.mp4
# 1
# .\data_subset\ap1_a75de2a6adfa9b24\faces
# Copying to :.\temp_fake_faces\
# aa2_15541b061aede1cc.mp4
# 1
# .\data_subset\aa2_15541b061aede1cc\faces
# Copying to :.\temp_fake_faces\
# aa2_636c48bbb4c236f3.mp4
# 1
# .\data_subset\aa2_636c48bbb4c236f3\faces
# Copying to :.\temp_fake_faces\
# aa2_7c451ecb4a2a579a.mp4
# 1
# .\data_subset\aa2_7c451ecb4a2a579a\faces
# Copying to :.\temp_fake_faces\
# aa2_e6f290c3e6ef6675.mp4
# 1
# .\data_subset\aa2_e6f290c3e6ef6675\faces
# Copying to :.\temp_fake_faces\
# aa1_ad8c6c1daa6c0e7e.mp4
# 1
# .\data_subset\aa1_ad8c6c1daa6c0e7e\faces
# Copying to :.\temp_fake_faces\
# aa1_8fadd7ba78807840.mp4
# 1
# .\data_subset\aa1_8fadd7ba78807840\faces
# Copying to :.\temp_fake_faces\
# aa1_a58f4defecdd5563.mp4
# 1
# .\data_subset\aa1_a58f4defecdd5563\faces
# Copying to :.\temp_fake_faces\
# aa1_341c5ea49c165c40.mp4
# 1
# .\data_subset\aa1_341c5ea49c165c40\faces
# Copying to :.\temp_fake_faces\
# aa1_c0fdb25d5bef0d2a.mp4
# 1
# .\data_subset\aa1_c0fdb25d5bef0d2a\faces
# Copying to :.\temp_fake_faces\
# aa1_c0a81a9d1a9ab155.mp4
# 1
# .\data_subset\aa1_c0a81a9d1a9ab155\faces
# Copying to :.\temp_fake_faces\
# aa1_d855a7acb20a87ac.mp4
# 1
# .\data_subset\aa1_d855a7acb20a87ac\faces
# Copying to :.\temp_fake_faces\
# aa1_503bcb5d3e2dfeaf.mp4
# 1
# .\data_subset\aa1_503bcb5d3e2dfeaf\faces
# Copying to :.\temp_fake_faces\
# aa1_3170132f8ec53713.mp4
# 1
# .\data_subset\aa1_3170132f8ec53713\faces
# Copying to :.\temp_fake_faces\
# aa1_e98ff9de751839a9.mp4
# 1
# .\data_subset\aa1_e98ff9de751839a9\faces
# Copying to :.\temp_fake_faces\
# aa1_8e984281448be905.mp4
# 1
# .\data_subset\aa1_8e984281448be905\faces
# Copying to :.\temp_fake_faces\
# aa1_1c52c8c04d953a31.mp4
# 1
# .\data_subset\aa1_1c52c8c04d953a31\faces
# Copying to :.\temp_fake_faces\
# aa2_70b5767ff3ada89c.mp4
# 1
# .\data_subset\aa2_70b5767ff3ada89c\faces
# Copying to :.\temp_fake_faces\
# aa2_2990baf5666a7cf0.mp4
# 1
# .\data_subset\aa2_2990baf5666a7cf0\faces
# Copying to :.\temp_fake_faces\
# aa2_dce1d756e91a2789.mp4
# 1
# .\data_subset\aa2_dce1d756e91a2789\faces
# Copying to :.\temp_fake_faces\
# aa2_52b48c0e6393ae07.mp4
# 1
# .\data_subset\aa2_52b48c0e6393ae07\faces
# Copying to :.\temp_fake_faces\
# aa1_9864ac68f5bc6f13.mp4
# 1
# .\data_subset\aa1_9864ac68f5bc6f13\faces
# Copying to :.\temp_fake_faces\
# aa1_1e82990a1a4a8e02.mp4
# 1
# .\data_subset\aa1_1e82990a1a4a8e02\faces
# Copying to :.\temp_fake_faces\
# aa1_bb2684d5a1aa8736.mp4
# 1
# .\data_subset\aa1_bb2684d5a1aa8736\faces
# Copying to :.\temp_fake_faces\
# aa1_6577fc24f25cd10e.mp4
# 1
# .\data_subset\aa1_6577fc24f25cd10e\faces
# Copying to :.\temp_fake_faces\
# ap1_8159b15a4bbe7e7f.mp4
# 1
# .\data_subset\ap1_8159b15a4bbe7e7f\faces
# Copying to :.\temp_fake_faces\
# ap1_5e747085f4a35978.mp4
# 1
# .\data_subset\ap1_5e747085f4a35978\faces
# Copying to :.\temp_fake_faces\
# ap1_4acd955e670d4f16.mp4
# 1
# .\data_subset\ap1_4acd955e670d4f16\faces
# Copying to :.\temp_fake_faces\
# ap1_9c978798c6af01b8.mp4
# 1
# .\data_subset\ap1_9c978798c6af01b8\faces
# Copying to :.\temp_fake_faces\
# ap1_a4b637801f03c7e8.mp4
# 1
# .\data_subset\ap1_a4b637801f03c7e8\faces
# Copying to :.\temp_fake_faces\
# ap1_525b5d9ca25afeb6.mp4
# 1
# .\data_subset\ap1_525b5d9ca25afeb6\faces
# Copying to :.\temp_fake_faces\
# ap1_2e29ad0b8891dfdf.mp4
# 1
# .\data_subset\ap1_2e29ad0b8891dfdf\faces
# Copying to :.\temp_fake_faces\
# ap1_9fe8b7e3403a970a.mp4
# 1
# .\data_subset\ap1_9fe8b7e3403a970a\faces
# Copying to :.\temp_fake_faces\
# pa1_1b2559b845b702ed.mp4
# 1
# .\data_subset\pa1_1b2559b845b702ed\faces
# Copying to :.\temp_fake_faces\
# pa1_ea10fec26dc65d23.mp4
# 1
# .\data_subset\pa1_ea10fec26dc65d23\faces
# Copying to :.\temp_fake_faces\
# pa1_dc81b912229aa06d.mp4
# 1
# .\data_subset\pa1_dc81b912229aa06d\faces
# Copying to :.\temp_fake_faces\
# pa1_dea3e02a2a680b5e.mp4
# 1
# .\data_subset\pa1_dea3e02a2a680b5e\faces
# Copying to :.\temp_fake_faces\
# ap1_7716a9aafaf6b801.mp4
# 1
# .\data_subset\ap1_7716a9aafaf6b801\faces
# Copying to :.\temp_fake_faces\
# ap1_3cf9172cd6a2d0ca.mp4
# 1
# .\data_subset\ap1_3cf9172cd6a2d0ca\faces
# Copying to :.\temp_fake_faces\
# ap1_a92b335f23f36f7a.mp4
# 1
# .\data_subset\ap1_a92b335f23f36f7a\faces
# Copying to :.\temp_fake_faces\
# ap1_2da1a66c34539baf.mp4
# 1
# .\data_subset\ap1_2da1a66c34539baf\faces
# Copying to :.\temp_fake_faces\
# pa2_b42c7ed7efbcacde.mp4
# 1
# .\data_subset\pa2_b42c7ed7efbcacde\faces
# Copying to :.\temp_fake_faces\
# pa2_a8f052dc2ac086e0.mp4
# 1
# .\data_subset\pa2_a8f052dc2ac086e0\faces
# Copying to :.\temp_fake_faces\
# pa2_1365cd6cefc6de10.mp4
# 1
# .\data_subset\pa2_1365cd6cefc6de10\faces
# Copying to :.\temp_fake_faces\
# pa2_c9123bd78d6e21e9.mp4
# 1
# .\data_subset\pa2_c9123bd78d6e21e9\faces
# Copying to :.\temp_fake_faces\
# pa2_084d961c6208ecfd.mp4
# 1
# .\data_subset\pa2_084d961c6208ecfd\faces
# Copying to :.\temp_fake_faces\
# pa2_1912a9a006500ab5.mp4
# 1
# .\data_subset\pa2_1912a9a006500ab5\faces
# Copying to :.\temp_fake_faces\
# pa2_0b96d7ed017f89a5.mp4
# 1
# .\data_subset\pa2_0b96d7ed017f89a5\faces
# Copying to :.\temp_fake_faces\
# pa2_e3c466485aab8da2.mp4
# 1
# .\data_subset\pa2_e3c466485aab8da2\faces
# Copying to :.\temp_fake_faces\
# ap1_af4134c46810953c.mp4
# 1
# .\data_subset\ap1_af4134c46810953c\faces
# Copying to :.\temp_fake_faces\
# ap1_938bbf3c6774ebb5.mp4
# 1
# .\data_subset\ap1_938bbf3c6774ebb5\faces
# Copying to :.\temp_fake_faces\
# ap1_8fbf5076069d8247.mp4
# 1
# .\data_subset\ap1_8fbf5076069d8247\faces
# Copying to :.\temp_fake_faces\
# ap1_52c69b6ced1698b6.mp4
# 1
# .\data_subset\ap1_52c69b6ced1698b6\faces
# Copying to :.\temp_fake_faces\
# ap2_335d2194f902401e.mp4
# 1
# .\data_subset\ap2_335d2194f902401e\faces
# Copying to :.\temp_fake_faces\
# ap2_17ae79407330b87b.mp4
# 1
# .\data_subset\ap2_17ae79407330b87b\faces
# Copying to :.\temp_fake_faces\
# ap2_e690fe7f635f5620.mp4
# 1
# .\data_subset\ap2_e690fe7f635f5620\faces
# Copying to :.\temp_fake_faces\
# ap2_6bbf4b0c349ee94c.mp4
# 1
# .\data_subset\ap2_6bbf4b0c349ee94c\faces
# Copying to :.\temp_fake_faces\
# aa1_982fc90b93b4e6a4.mp4
# 1
# .\data_subset\aa1_982fc90b93b4e6a4\faces
# Copying to :.\temp_fake_faces\
# aa1_a46016c3c9a0608f.mp4
# 1
# .\data_subset\aa1_a46016c3c9a0608f\faces
# Copying to :.\temp_fake_faces\
# aa1_3a26f5a535ab72f8.mp4
# 1
# .\data_subset\aa1_3a26f5a535ab72f8\faces
# Copying to :.\temp_fake_faces\
# aa1_af7c7b27e51b3e83.mp4
# 1
# .\data_subset\aa1_af7c7b27e51b3e83\faces
# Copying to :.\temp_fake_faces\
# ap2_65d6d5d3d741ad5d.mp4
# 1
# .\data_subset\ap2_65d6d5d3d741ad5d\faces
# Copying to :.\temp_fake_faces\
# ap2_28f42e63e299350c.mp4
# 1
# .\data_subset\ap2_28f42e63e299350c\faces
# Copying to :.\temp_fake_faces\
# ap2_ecd342370b1e0916.mp4
# 1
# .\data_subset\ap2_ecd342370b1e0916\faces
# Copying to :.\temp_fake_faces\
# ap2_1acfde344b78f925.mp4
# 1
# .\data_subset\ap2_1acfde344b78f925\faces
# Copying to :.\temp_fake_faces\
# ap1_c6eb37bbd3cd36f4.mp4
# 1
# .\data_subset\ap1_c6eb37bbd3cd36f4\faces
# Copying to :.\temp_fake_faces\
# ap1_cbb73bd8e090194b.mp4
# 1
# .\data_subset\ap1_cbb73bd8e090194b\faces
# Copying to :.\temp_fake_faces\
# ap1_f331309264e6351f.mp4
# 1
# .\data_subset\ap1_f331309264e6351f\faces
# Copying to :.\temp_fake_faces\
# ap1_9166181f0985066b.mp4
# 1
# .\data_subset\ap1_9166181f0985066b\faces
# Copying to :.\temp_fake_faces\
# ap1_7cdc22a1bc90c863.mp4
# 1
# .\data_subset\ap1_7cdc22a1bc90c863\faces
# Copying to :.\temp_fake_faces\
# ap1_b3a78690e3a3e0de.mp4
# 1
# .\data_subset\ap1_b3a78690e3a3e0de\faces
# Copying to :.\temp_fake_faces\
# ap1_0cdc61c98d3a7272.mp4
# 1
# .\data_subset\ap1_0cdc61c98d3a7272\faces
# Copying to :.\temp_fake_faces\
# ap1_1a4852339c230a5f.mp4
# 1
# .\data_subset\ap1_1a4852339c230a5f\faces
# Copying to :.\temp_fake_faces\
# ap1_811c3139a308feaa.mp4
# 1
# .\data_subset\ap1_811c3139a308feaa\faces
# Copying to :.\temp_fake_faces\
# ap1_e52695117480351a.mp4
# 1
# .\data_subset\ap1_e52695117480351a\faces
# Copying to :.\temp_fake_faces\
# aa2_edd32159815c1a28.mp4
# 1
# .\data_subset\aa2_edd32159815c1a28\faces
# Copying to :.\temp_fake_faces\
# aa2_83f96e4652c777f6.mp4
# 1
# .\data_subset\aa2_83f96e4652c777f6\faces
# Copying to :.\temp_fake_faces\
# aa2_bfb3fe944daf1720.mp4
# 1
# .\data_subset\aa2_bfb3fe944daf1720\faces
# Copying to :.\temp_fake_faces\
# aa2_f202633bf8803e30.mp4
# 1
# .\data_subset\aa2_f202633bf8803e30\faces
# Copying to :.\temp_fake_faces\
# aa2_4931eb449df87add.mp4
# 1
# .\data_subset\aa2_4931eb449df87add\faces
# Copying to :.\temp_fake_faces\
# aa2_b42d73d9c54fde00.mp4
# 1
# .\data_subset\aa2_b42d73d9c54fde00\faces
# Copying to :.\temp_fake_faces\
# aa2_f2f0eed95d5b9c56.mp4
# 1
# .\data_subset\aa2_f2f0eed95d5b9c56\faces
# Copying to :.\temp_fake_faces\
# aa2_b2c41c9c993d1237.mp4
# 1
# .\data_subset\aa2_b2c41c9c993d1237\faces
# Copying to :.\temp_fake_faces\
# aa1_8078569f9f3e7e64.mp4
# 1
# .\data_subset\aa1_8078569f9f3e7e64\faces
# Copying to :.\temp_fake_faces\
# aa1_ac9e97c6fac9f63c.mp4
# 1
# .\data_subset\aa1_ac9e97c6fac9f63c\faces
# Copying to :.\temp_fake_faces\
# aa1_ac9af09efa598131.mp4
# 1
# .\data_subset\aa1_ac9af09efa598131\faces
# Copying to :.\temp_fake_faces\
# aa2_67978dfebba5a107.mp4
# 1
# .\data_subset\aa2_67978dfebba5a107\faces
# Copying to :.\temp_fake_faces\
# aa2_8a3f1f8ff933a1ec.mp4
# 1
# .\data_subset\aa2_8a3f1f8ff933a1ec\faces
# Copying to :.\temp_fake_faces\
# aa2_b55a583e1f67ca78.mp4
# 1
# .\data_subset\aa2_b55a583e1f67ca78\faces
# Copying to :.\temp_fake_faces\
# aa2_337e4a2cdc98f7d4.mp4
# 1
# .\data_subset\aa2_337e4a2cdc98f7d4\faces
# Copying to :.\temp_fake_faces\
# aa1_975c1efdc9ce1987.mp4
# 1
# .\data_subset\aa1_975c1efdc9ce1987\faces
# Copying to :.\temp_fake_faces\
# aa1_4aafb59006786d02.mp4
# 1
# .\data_subset\aa1_4aafb59006786d02\faces
# Copying to :.\temp_fake_faces\
# aa1_dffe2a35497529b6.mp4
# 1
# .\data_subset\aa1_dffe2a35497529b6\faces
# Copying to :.\temp_fake_faces\
# aa1_2d25b00d843f9062.mp4
# 1
# .\data_subset\aa1_2d25b00d843f9062\faces
# Copying to :.\temp_fake_faces\
# aa2_08762c8cad9c8b17.mp4
# 1
# .\data_subset\aa2_08762c8cad9c8b17\faces
# Copying to :.\temp_fake_faces\
# aa2_5f7b32c9a7fffc3f.mp4
# 1
# .\data_subset\aa2_5f7b32c9a7fffc3f\faces
# Copying to :.\temp_fake_faces\
# aa2_06b9bbc4c0e10dc3.mp4
# 1
# .\data_subset\aa2_06b9bbc4c0e10dc3\faces
# Copying to :.\temp_fake_faces\
# aa2_416a58f9ce078c23.mp4
# 1
# .\data_subset\aa2_416a58f9ce078c23\faces
# Copying to :.\temp_fake_faces\
# aa2_e07234f079e27560.mp4
# 1
# .\data_subset\aa2_e07234f079e27560\faces
# Copying to :.\temp_fake_faces\
# aa2_ab89bccc3498214f.mp4
# 1
# .\data_subset\aa2_ab89bccc3498214f\faces
# Copying to :.\temp_fake_faces\
# aa2_8364bb586e0b9e3c.mp4
# 1
# .\data_subset\aa2_8364bb586e0b9e3c\faces
# Copying to :.\temp_fake_faces\
# aa2_f95b4267d00d621a.mp4
# 1
# .\data_subset\aa2_f95b4267d00d621a\faces
# Copying to :.\temp_fake_faces\
# pa1_1b3685679120c9f4.mp4
# 1
# .\data_subset\pa1_1b3685679120c9f4\faces
# Copying to :.\temp_fake_faces\
# pa1_7f6ff4ba24146b85.mp4
# 1
# .\data_subset\pa1_7f6ff4ba24146b85\faces
# Copying to :.\temp_fake_faces\
# pa1_676556f2dafe6cd0.mp4
# 1
# .\data_subset\pa1_676556f2dafe6cd0\faces
# Copying to :.\temp_fake_faces\
# pa1_5dd948e6b7179f81.mp4
# 1
# .\data_subset\pa1_5dd948e6b7179f81\faces
# Copying to :.\temp_fake_faces\
# pa1_bef9ce3572e5f63f.mp4
# 1
# .\data_subset\pa1_bef9ce3572e5f63f\faces
# Copying to :.\temp_fake_faces\
# pa1_180fd81f13f01f6d.mp4
# 1
# .\data_subset\pa1_180fd81f13f01f6d\faces
# Copying to :.\temp_fake_faces\
# ap2_a3e325de573db7da.mp4
# 1
# .\data_subset\ap2_a3e325de573db7da\faces
# Copying to :.\temp_fake_faces\
# ap2_4eba288d2db07a13.mp4
# 1
# .\data_subset\ap2_4eba288d2db07a13\faces
# Copying to :.\temp_fake_faces\
# ap2_9d4cf95f0e90b05e.mp4
# 1
# .\data_subset\ap2_9d4cf95f0e90b05e\faces
# Copying to :.\temp_fake_faces\
# ap2_96cf30e1c2eafd09.mp4
# 1
# .\data_subset\ap2_96cf30e1c2eafd09\faces
# Copying to :.\temp_fake_faces\
# aa1_bf39bb7db256523b.mp4
# 1
# .\data_subset\aa1_bf39bb7db256523b\faces
# Copying to :.\temp_fake_faces\
# aa1_7f0cfda5d5f5bd51.mp4
# 1
# .\data_subset\aa1_7f0cfda5d5f5bd51\faces
# Copying to :.\temp_fake_faces\
# aa1_d9700f6bfd3bd3b6.mp4
# 1
# .\data_subset\aa1_d9700f6bfd3bd3b6\faces
# Copying to :.\temp_fake_faces\
# aa1_592be9550a8335f3.mp4
# 1
# .\data_subset\aa1_592be9550a8335f3\faces
# Copying to :.\temp_fake_faces\
# aa2_3f2f5215b50a5109.mp4
# 1
# .\data_subset\aa2_3f2f5215b50a5109\faces
# Copying to :.\temp_fake_faces\
# aa2_f2ae9b26e3295926.mp4
# 1
# .\data_subset\aa2_f2ae9b26e3295926\faces
# Copying to :.\temp_fake_faces\
# aa2_beaba4fdeee472cf.mp4
# 1
# .\data_subset\aa2_beaba4fdeee472cf\faces
# Copying to :.\temp_fake_faces\
# aa2_e12033fd6e50d34d.mp4
# 1
# .\data_subset\aa2_e12033fd6e50d34d\faces
# Copying to :.\temp_fake_faces\
# ap2_ed801688a4ccc382.mp4
# 1
# .\data_subset\ap2_ed801688a4ccc382\faces
# Copying to :.\temp_fake_faces\
# ap2_0f618883b4577d88.mp4
# 1
# .\data_subset\ap2_0f618883b4577d88\faces
# Copying to :.\temp_fake_faces\
# ap2_b3fd419ec2517bee.mp4
# 1
# .\data_subset\ap2_b3fd419ec2517bee\faces
# Copying to :.\temp_fake_faces\
# ap2_a81568e1f0506614.mp4
# 1
# .\data_subset\ap2_a81568e1f0506614\faces
# Copying to :.\temp_fake_faces\
# pa1_1f14b2bf43abafcc.mp4
# 1
# .\data_subset\pa1_1f14b2bf43abafcc\faces
# Copying to :.\temp_fake_faces\
# pa1_c78ee6e595842685.mp4
# 1
# .\data_subset\pa1_c78ee6e595842685\faces
# Copying to :.\temp_fake_faces\
# pa1_12ca8404205230a9.mp4
# 1
# .\data_subset\pa1_12ca8404205230a9\faces
# Copying to :.\temp_fake_faces\
# pa1_fe7bb63c4f1a2c03.mp4
# 1
# .\data_subset\pa1_fe7bb63c4f1a2c03\faces
# Copying to :.\temp_fake_faces\
# pa1_3e96ee2bcf184b5a.mp4
# 1
# .\data_subset\pa1_3e96ee2bcf184b5a\faces
# Copying to :.\temp_fake_faces\
# pa1_8eff7b1423da8cf8.mp4
# 1
# .\data_subset\pa1_8eff7b1423da8cf8\faces
# Copying to :.\temp_fake_faces\
# pa1_236f78bbefa3b722.mp4
# 1
# .\data_subset\pa1_236f78bbefa3b722\faces
# Copying to :.\temp_fake_faces\
# pa1_57b6e8b44c704847.mp4
# 1
# .\data_subset\pa1_57b6e8b44c704847\faces
# Copying to :.\temp_fake_faces\
# pa2_0feca2d6f8d1f891.mp4
# 1
# .\data_subset\pa2_0feca2d6f8d1f891\faces
# Copying to :.\temp_fake_faces\
# pa2_e9f39795da43efc9.mp4
# 1
# .\data_subset\pa2_e9f39795da43efc9\faces
# Copying to :.\temp_fake_faces\
# pa2_556ad6f3b71755bb.mp4
# 1
# .\data_subset\pa2_556ad6f3b71755bb\faces
# Copying to :.\temp_fake_faces\
# pa2_bb6df5fb84e933f6.mp4
# 1
# .\data_subset\pa2_bb6df5fb84e933f6\faces
# Copying to :.\temp_fake_faces\
# ap1_1a73c5e343b51bec.mp4
# 1
# .\data_subset\ap1_1a73c5e343b51bec\faces
# Copying to :.\temp_fake_faces\
# ap1_e5cefab02a629d06.mp4
# 1
# .\data_subset\ap1_e5cefab02a629d06\faces
# Copying to :.\temp_fake_faces\
# ap1_e751cbd709d60b2a.mp4
# 1
# .\data_subset\ap1_e751cbd709d60b2a\faces
# Copying to :.\temp_fake_faces\
# ap1_038ba87827a9f1b4.mp4
# 1
# .\data_subset\ap1_038ba87827a9f1b4\faces
# Copying to :.\temp_fake_faces\
# pa1_7822c6ecd2cc37d4.mp4
# 1
# .\data_subset\pa1_7822c6ecd2cc37d4\faces
# Copying to :.\temp_fake_faces\
# pa1_8d1e14e1259e7848.mp4
# 1
# .\data_subset\pa1_8d1e14e1259e7848\faces
# Copying to :.\temp_fake_faces\
# pa1_7b703625853ba206.mp4
# 1
# .\data_subset\pa1_7b703625853ba206\faces
# Copying to :.\temp_fake_faces\
# pa1_e4fb3c7263a056a9.mp4
# 1
# .\data_subset\pa1_e4fb3c7263a056a9\faces
# Copying to :.\temp_fake_faces\
# pa1_5be21dce9c533de8.mp4
# 1
# .\data_subset\pa1_5be21dce9c533de8\faces
# Copying to :.\temp_fake_faces\
# pa1_ba211079a5a147aa.mp4
# 1
# .\data_subset\pa1_ba211079a5a147aa\faces
# Copying to :.\temp_fake_faces\
# pa1_558d0941d0b93c4c.mp4
# 1
# .\data_subset\pa1_558d0941d0b93c4c\faces
# Copying to :.\temp_fake_faces\
# pa1_e7116f9e8235d18a.mp4
# 1
# .\data_subset\pa1_e7116f9e8235d18a\faces
# Copying to :.\temp_fake_faces\
# pa2_2ba17b76b3627a38.mp4
# 1
# .\data_subset\pa2_2ba17b76b3627a38\faces
# Copying to :.\temp_fake_faces\
# pa2_cf725db7faa28948.mp4
# 1
# .\data_subset\pa2_cf725db7faa28948\faces
# Copying to :.\temp_fake_faces\
# pa2_edbdaf1b737f01e3.mp4
# 1
# .\data_subset\pa2_edbdaf1b737f01e3\faces
# Copying to :.\temp_fake_faces\
# pa2_8adbfd3fe2f75692.mp4
# 1
# .\data_subset\pa2_8adbfd3fe2f75692\faces
# Copying to :.\temp_fake_faces\
# ap2_cb99d3e95dc0b0c8.mp4
# 1
# .\data_subset\ap2_cb99d3e95dc0b0c8\faces
# Copying to :.\temp_fake_faces\
# ap2_0ae1576c58393c78.mp4
# 1
# .\data_subset\ap2_0ae1576c58393c78\faces
# Copying to :.\temp_fake_faces\
# ap2_f888059d943b9810.mp4
# 1
# .\data_subset\ap2_f888059d943b9810\faces
# Copying to :.\temp_fake_faces\
# ap2_b78f40531c198577.mp4
# 1
# .\data_subset\ap2_b78f40531c198577\faces
# Copying to :.\temp_fake_faces\
# ap1_d0829f26a7374271.mp4
# 1
# .\data_subset\ap1_d0829f26a7374271\faces
# Copying to :.\temp_fake_faces\
# ap1_48f8fa0866f60c72.mp4
# 1
# .\data_subset\ap1_48f8fa0866f60c72\faces
# Copying to :.\temp_fake_faces\
# ap1_5a43af6b362136ef.mp4
# 1
# .\data_subset\ap1_5a43af6b362136ef\faces
# Copying to :.\temp_fake_faces\
# ap1_f5a55b323ad85a79.mp4
# 1
# .\data_subset\ap1_f5a55b323ad85a79\faces
# Copying to :.\temp_fake_faces\
# ap1_163f6af7c97ba233.mp4
# 1
# .\data_subset\ap1_163f6af7c97ba233\faces
# Copying to :.\temp_fake_faces\
# ap1_ff6f280718d43118.mp4
# 1
# .\data_subset\ap1_ff6f280718d43118\faces
# Copying to :.\temp_fake_faces\
# ap1_d0f24c3f050cc763.mp4
# 1
# .\data_subset\ap1_d0f24c3f050cc763\faces
# Copying to :.\temp_fake_faces\
# ap1_26d1ebac5edddb08.mp4
# 1
# .\data_subset\ap1_26d1ebac5edddb08\faces
# Copying to :.\temp_fake_faces\
# pa1_205f0a5b41d57c44.mp4
# 1
# .\data_subset\pa1_205f0a5b41d57c44\faces
# Copying to :.\temp_fake_faces\
# pa1_57a607f8b0d25938.mp4
# 1
# .\data_subset\pa1_57a607f8b0d25938\faces
# Copying to :.\temp_fake_faces\
# pa1_0cdd22981d563ee2.mp4
# 1
# .\data_subset\pa1_0cdd22981d563ee2\faces
# Copying to :.\temp_fake_faces\
# pa1_dadad18f7c332b45.mp4
# 1
# .\data_subset\pa1_dadad18f7c332b45\faces
# Copying to :.\temp_fake_faces\
# pa2_13c951bde95dff7c.mp4
# 1
# .\data_subset\pa2_13c951bde95dff7c\faces
# Copying to :.\temp_fake_faces\
# pa2_5ed5a5d1a29732b0.mp4
# 1
# .\data_subset\pa2_5ed5a5d1a29732b0\faces
# Copying to :.\temp_fake_faces\
# pa2_7ef7bca852136302.mp4
# 1
# .\data_subset\pa2_7ef7bca852136302\faces
# Copying to :.\temp_fake_faces\
# pa2_0e2b0420d5b855f6.mp4
# 1
# .\data_subset\pa2_0e2b0420d5b855f6\faces
# Copying to :.\temp_fake_faces\
# aa2_14fdf6e4a7650aae.mp4
# 1
# .\data_subset\aa2_14fdf6e4a7650aae\faces
# Copying to :.\temp_fake_faces\
# aa2_9ab60c3c69d77193.mp4
# 1
# .\data_subset\aa2_9ab60c3c69d77193\faces
# Copying to :.\temp_fake_faces\
# aa2_9550cad1538951b3.mp4
# 1
# .\data_subset\aa2_9550cad1538951b3\faces
# Copying to :.\temp_fake_faces\
# aa2_3d63d8d14bbd9fdf.mp4
# 1
# .\data_subset\aa2_3d63d8d14bbd9fdf\faces
# Copying to :.\temp_fake_faces\
# pa2_279731e4cbb0750a.mp4
# 1
# .\data_subset\pa2_279731e4cbb0750a\faces
# Copying to :.\temp_fake_faces\
# pa2_25c850e26292af63.mp4
# 1
# .\data_subset\pa2_25c850e26292af63\faces
# Copying to :.\temp_fake_faces\
# pa2_f31201dbbd337879.mp4
# 1
# .\data_subset\pa2_f31201dbbd337879\faces
# Copying to :.\temp_fake_faces\
# pa2_90acadcf557b5758.mp4
# 1
# .\data_subset\pa2_90acadcf557b5758\faces
# Copying to :.\temp_fake_faces\
# ap2_29aa5be07d4f179e.mp4
# 1
# .\data_subset\ap2_29aa5be07d4f179e\faces
# Copying to :.\temp_fake_faces\
# ap2_a292deb64299d9fe.mp4
# 1
# .\data_subset\ap2_a292deb64299d9fe\faces
# Copying to :.\temp_fake_faces\
# ap2_302df6a65af7fe06.mp4
# 1
# .\data_subset\ap2_302df6a65af7fe06\faces
# Copying to :.\temp_fake_faces\
# ap2_3dc68cd0a75f9d68.mp4
# 1
# .\data_subset\ap2_3dc68cd0a75f9d68\faces
# Copying to :.\temp_fake_faces\
# pa1_4b8b464b8da44ad0.mp4
# 1
# .\data_subset\pa1_4b8b464b8da44ad0\faces
# Copying to :.\temp_fake_faces\
# pa1_7250d2327f1d4300.mp4
# 1
# .\data_subset\pa1_7250d2327f1d4300\faces
# Copying to :.\temp_fake_faces\
# pa1_2ba162062ff98581.mp4
# 1
# .\data_subset\pa1_2ba162062ff98581\faces
# Copying to :.\temp_fake_faces\
# pa1_cbdd5f57b2c51043.mp4
# 1
# .\data_subset\pa1_cbdd5f57b2c51043\faces
# Copying to :.\temp_fake_faces\
# pa2_c56c3a2f6c828239.mp4
# 1
# .\data_subset\pa2_c56c3a2f6c828239\faces
# Copying to :.\temp_fake_faces\
# pa2_cbb4bc78ddb375df.mp4
# 1
# .\data_subset\pa2_cbb4bc78ddb375df\faces
# Copying to :.\temp_fake_faces\
# pa2_327aa55f6d75bd5f.mp4
# 1
# .\data_subset\pa2_327aa55f6d75bd5f\faces
# Copying to :.\temp_fake_faces\
# pa2_41f8f22be82ebaff.mp4
# 1
# .\data_subset\pa2_41f8f22be82ebaff\faces
# Copying to :.\temp_fake_faces\
# pa1_b25fb5200791cb83.mp4
# 1
# .\data_subset\pa1_b25fb5200791cb83\faces
# Copying to :.\temp_fake_faces\
# pa1_9cd14b6473aa67e4.mp4
# 1
# .\data_subset\pa1_9cd14b6473aa67e4\faces
# Copying to :.\temp_fake_faces\
# pa1_153aba5f45d75f87.mp4
# 1
# .\data_subset\pa1_153aba5f45d75f87\faces
# Copying to :.\temp_fake_faces\
# pa1_8087d150b29c899a.mp4
# 1
# .\data_subset\pa1_8087d150b29c899a\faces
# Copying to :.\temp_fake_faces\
# aa2_4055ae6865a7830e.mp4
# 1
# .\data_subset\aa2_4055ae6865a7830e\faces
# Copying to :.\temp_fake_faces\
# aa2_8fde03b1c1188280.mp4
# 1
# .\data_subset\aa2_8fde03b1c1188280\faces
# Copying to :.\temp_fake_faces\
# aa2_ad7f1181c9dc9ed2.mp4
# 1
# .\data_subset\aa2_ad7f1181c9dc9ed2\faces
# Copying to :.\temp_fake_faces\
# aa2_b751ad80363034db.mp4
# 1
# .\data_subset\aa2_b751ad80363034db\faces
# Copying to :.\temp_fake_faces\
# ap2_f45a1fd86d66e669.mp4
# 1
# .\data_subset\ap2_f45a1fd86d66e669\faces
# Copying to :.\temp_fake_faces\
# ap2_07bb247b0cdfefc6.mp4
# 1
# .\data_subset\ap2_07bb247b0cdfefc6\faces
# Copying to :.\temp_fake_faces\
# ap2_3a14d63ba17ea2b1.mp4
# 1
# .\data_subset\ap2_3a14d63ba17ea2b1\faces
# Copying to :.\temp_fake_faces\
# ap2_0695d9dbed7c66c7.mp4
# 1
# .\data_subset\ap2_0695d9dbed7c66c7\faces
# Copying to :.\temp_fake_faces\
# pa1_88ed69cb6cf1cad7.mp4
# 1
# .\data_subset\pa1_88ed69cb6cf1cad7\faces
# Copying to :.\temp_fake_faces\
# pa1_eee2717d406f719d.mp4
# 1
# .\data_subset\pa1_eee2717d406f719d\faces
# Copying to :.\temp_fake_faces\
# pa1_296cbf1b858aadde.mp4
# 1
# .\data_subset\pa1_296cbf1b858aadde\faces
# Copying to :.\temp_fake_faces\
# pa1_a78cbf18d10ac1a9.mp4
# 1
# .\data_subset\pa1_a78cbf18d10ac1a9\faces
# Copying to :.\temp_fake_faces\
# pa2_b9e764b8d21fe628.mp4
# 1
# .\data_subset\pa2_b9e764b8d21fe628\faces
# Copying to :.\temp_fake_faces\
# pa2_c51dc04b079c99d2.mp4
# 1
# .\data_subset\pa2_c51dc04b079c99d2\faces
# Copying to :.\temp_fake_faces\
# pa2_d315fdc1081011cd.mp4
# 1
# .\data_subset\pa2_d315fdc1081011cd\faces
# Copying to :.\temp_fake_faces\
# pa2_5eef506dbb0c523b.mp4
# 1
# .\data_subset\pa2_5eef506dbb0c523b\faces
# Copying to :.\temp_fake_faces\
# pa2_7aa85f1f78cc6c26.mp4
# 1
# .\data_subset\pa2_7aa85f1f78cc6c26\faces
# Copying to :.\temp_fake_faces\
# pa2_38a188839ffb331d.mp4
# 1
# .\data_subset\pa2_38a188839ffb331d\faces
# Copying to :.\temp_fake_faces\
# pa2_ff4d91f4edc5abce.mp4
# 1
# .\data_subset\pa2_ff4d91f4edc5abce\faces
# Copying to :.\temp_fake_faces\
# pa2_96a28f84311df44c.mp4
# 1
# .\data_subset\pa2_96a28f84311df44c\faces
# Copying to :.\temp_fake_faces\
# pa2_78f01317dc96dfa3.mp4
# 1
# .\data_subset\pa2_78f01317dc96dfa3\faces
# Copying to :.\temp_fake_faces\
# pa2_3d6b138960c07331.mp4
# 1
# .\data_subset\pa2_3d6b138960c07331\faces
# Copying to :.\temp_fake_faces\
# pa2_eae426d5c0c0fdfd.mp4
# 1
# .\data_subset\pa2_eae426d5c0c0fdfd\faces
# Copying to :.\temp_fake_faces\
# pa2_2c761ec9ea811d05.mp4
# 1
# .\data_subset\pa2_2c761ec9ea811d05\faces
# Copying to :.\temp_fake_faces\
# ap2_df937bae700a1d46.mp4
# 1
# .\data_subset\ap2_df937bae700a1d46\faces
# Copying to :.\temp_fake_faces\
# ap2_ae01015ddb027a52.mp4
# 1
# .\data_subset\ap2_ae01015ddb027a52\faces
# Copying to :.\temp_fake_faces\
# ap2_a597116276ac2875.mp4
# 1
# .\data_subset\ap2_a597116276ac2875\faces
# Copying to :.\temp_fake_faces\
# aa1_ae25c3be871f892b.mp4
# 1
# .\data_subset\aa1_ae25c3be871f892b\faces
# Copying to :.\temp_fake_faces\
# aa1_2c1a00cfd70f392d.mp4
# 1
# .\data_subset\aa1_2c1a00cfd70f392d\faces
# Copying to :.\temp_fake_faces\
# aa1_023493168e4c9574.mp4
# 1
# .\data_subset\aa1_023493168e4c9574\faces
# Copying to :.\temp_fake_faces\
# aa1_6a2436da19fc9f60.mp4
# 1
# .\data_subset\aa1_6a2436da19fc9f60\faces
# Copying to :.\temp_fake_faces\
# aa1_91f407704a65ff15.mp4
# 1
# .\data_subset\aa1_91f407704a65ff15\faces
# Copying to :.\temp_fake_faces\
# aa1_6d93605f67c3e53b.mp4
# 1
# .\data_subset\aa1_6d93605f67c3e53b\faces
# ...
# p00_0b9e5dfbece55853.mp4
# 0
# .\data_subset\p00_0b9e5dfbece55853\faces
# Copying to :.\temp_real_faces\
# p00_1613b97506f72e8a.mp4
# 0
# .\data_subset\p00_1613b97506f72e8a\faces
# Copying to :.\temp_real_faces\
# p00_c2e45667f8153f27.mp4
# 0
# .\data_subset\p00_c2e45667f8153f27\faces
# Copying to :.\temp_real_faces\
# p00_fdc933fcd5c6a990.mp4
# 0
# .\data_subset\p00_fdc933fcd5c6a990\faces
# Copying to :.\temp_real_faces\
# p00_d2c349299f493ccc.mp4
# 0
# .\data_subset\p00_d2c349299f493ccc\faces
# Copying to :.\temp_real_faces\
# a00_50ed9a5a428a3651.mp4
# 0
# .\data_subset\a00_50ed9a5a428a3651\faces
# Copying to :.\temp_real_faces\
# p00_b619b001ca6127dc.mp4
# 0
# .\data_subset\p00_b619b001ca6127dc\faces
# Copying to :.\temp_real_faces\
# a00_0e905a6924575399.mp4
# 0
# .\data_subset\a00_0e905a6924575399\faces
# Copying to :.\temp_real_faces\
# p00_21de66005b754d18.mp4
# 0
# .\data_subset\p00_21de66005b754d18\faces
# Copying to :.\temp_real_faces\
# a00_3500c69ed8665eea.mp4
# 0
# .\data_subset\a00_3500c69ed8665eea\faces
# Copying to :.\temp_real_faces\
# a00_d30576149a1c89f2.mp4
# 0
# .\data_subset\a00_d30576149a1c89f2\faces
# Copying to :.\temp_real_faces\
# a00_b45281787561a139.mp4
# 0
# .\data_subset\a00_b45281787561a139\faces
# Copying to :.\temp_real_faces\
# a00_5f5e44a88c8f258f.mp4
# 0
# .\data_subset\a00_5f5e44a88c8f258f\faces
# Copying to :.\temp_real_faces\
# a00_10f5dab9bc5fc3c2.mp4
# 0
# .\data_subset\a00_10f5dab9bc5fc3c2\faces
# Copying to :.\temp_real_faces\
# a00_240d6e492a205984.mp4
# 0
# .\data_subset\a00_240d6e492a205984\faces
# Copying to :.\temp_real_faces\
# a00_6acdd69301533376.mp4
# 0
# .\data_subset\a00_6acdd69301533376\faces
# Copying to :.\temp_real_faces\
# p00_0f6834ecd5f34d07.mp4
# 0
# .\data_subset\p00_0f6834ecd5f34d07\faces
# Copying to :.\temp_real_faces\
# a00_502a08c3fab41467.mp4
# 0
# .\data_subset\a00_502a08c3fab41467\faces
# Copying to :.\temp_real_faces\
# p00_bd7d1195346ae128.mp4
# 0
# .\data_subset\p00_bd7d1195346ae128\faces
# Copying to :.\temp_real_faces\
# p00_6c6971aadddc3359.mp4
# 0
# .\data_subset\p00_6c6971aadddc3359\faces
# Copying to :.\temp_real_faces\
# p00_a9df8458b205465f.mp4
# 0
# .\data_subset\p00_a9df8458b205465f\faces
# Copying to :.\temp_real_faces\
# p00_53e8904891df8cf6.mp4
# 0
# .\data_subset\p00_53e8904891df8cf6\faces
# Copying to :.\temp_real_faces\
# p00_d13aa50939ff2e66.mp4
# 0
# .\data_subset\p00_d13aa50939ff2e66\faces
# Copying to :.\temp_real_faces\
# a00_d51b46ba13703f03.mp4
# 0
# .\data_subset\a00_d51b46ba13703f03\faces
# Copying to :.\temp_real_faces\
# a00_466ddcd7a423b726.mp4
# 0
# .\data_subset\a00_466ddcd7a423b726\faces
# Copying to :.\temp_real_faces\
# p00_829037975faf90d3.mp4
# 0
# .\data_subset\p00_829037975faf90d3\faces
# Copying to :.\temp_real_faces\
# p00_bab1a2e25a2eb387.mp4
# 0
# .\data_subset\p00_bab1a2e25a2eb387\faces
# Copying to :.\temp_real_faces\
# p00_e73d4d468824ee68.mp4
# 0
# .\data_subset\p00_e73d4d468824ee68\faces
# Copying to :.\temp_real_faces\
# p00_99a4e471f839d8af.mp4
# 0
# .\data_subset\p00_99a4e471f839d8af\faces
# Copying to :.\temp_real_faces\
# p00_7c18bfa8a3a97e6d.mp4
# 0
# .\data_subset\p00_7c18bfa8a3a97e6d\faces
# Copying to :.\temp_real_faces\
# a00_fbe749bbdea95b39.mp4
# 0
# .\data_subset\a00_fbe749bbdea95b39\faces
# Copying to :.\temp_real_faces\
# a00_6a1f7a7095574091.mp4
# 0
# .\data_subset\a00_6a1f7a7095574091\faces
# Copying to :.\temp_real_faces\
# a00_fbfd2e4936d75134.mp4
# 0
# .\data_subset\a00_fbfd2e4936d75134\faces
# Copying to :.\temp_real_faces\
# a00_3f70b0e58cfd827d.mp4
# 0
# .\data_subset\a00_3f70b0e58cfd827d\faces
# Copying to :.\temp_real_faces\
# p00_3dc470e840d131a8.mp4
# 0
# .\data_subset\p00_3dc470e840d131a8\faces
# Copying to :.\temp_real_faces\
# a00_d0fe64de67325798.mp4
# 0
# .\data_subset\a00_d0fe64de67325798\faces
# Copying to :.\temp_real_faces\
# a00_737d0a39fa9092d9.mp4
# 0
# .\data_subset\a00_737d0a39fa9092d9\faces
# Copying to :.\temp_real_faces\
# a00_55efc510ccb6b565.mp4
# 0
# .\data_subset\a00_55efc510ccb6b565\faces
# Copying to :.\temp_real_faces\
# p00_c1c607b2a68ff992.mp4
# 0
# .\data_subset\p00_c1c607b2a68ff992\faces
# Copying to :.\temp_real_faces\
# a00_1cd55fc4af0efade.mp4
# 0
# .\data_subset\a00_1cd55fc4af0efade\faces
# Copying to :.\temp_real_faces\
# p00_de1b897f47900277.mp4
# 0
# .\data_subset\p00_de1b897f47900277\faces
# Copying to :.\temp_real_faces\
# a00_76624b9441a7042d.mp4
# 0
# .\data_subset\a00_76624b9441a7042d\faces
# Copying to :.\temp_real_faces\
# a00_c67151954f4f6130.mp4
# 0
# .\data_subset\a00_c67151954f4f6130\faces
# Copying to :.\temp_real_faces\
# p00_7d8d39dc531c4f25.mp4
# 0
# .\data_subset\p00_7d8d39dc531c4f25\faces
# Copying to :.\temp_real_faces\
# p00_97b8261bef8fae40.mp4
# 0
# .\data_subset\p00_97b8261bef8fae40\faces
# Copying to :.\temp_real_faces\
# p00_d98e1d564c7e86b4.mp4
# 0
# .\data_subset\p00_d98e1d564c7e86b4\faces
# Copying to :.\temp_real_faces\
# p00_d5842e08eb4f91dd.mp4
# 0
# .\data_subset\p00_d5842e08eb4f91dd\faces
# Copying to :.\temp_real_faces\
# a00_29feb7f881f3763e.mp4
# 0
# .\data_subset\a00_29feb7f881f3763e\faces
# Copying to :.\temp_real_faces\
# a00_df7218e2c0471e49.mp4
# 0
# .\data_subset\a00_df7218e2c0471e49\faces
# Copying to :.\temp_real_faces\
# p00_4848199522660ca0.mp4
# 0
# .\data_subset\p00_4848199522660ca0\faces
# Copying to :.\temp_real_faces\
# a00_f09d5fb669274f33.mp4
# 0
# .\data_subset\a00_f09d5fb669274f33\faces
# Copying to :.\temp_real_faces\
# p00_88aa8bc923fc65e1.mp4
# 0
# .\data_subset\p00_88aa8bc923fc65e1\faces
# Copying to :.\temp_real_faces\
# a00_eebd08123fd16a90.mp4
# 0
# .\data_subset\a00_eebd08123fd16a90\faces
# Copying to :.\temp_real_faces\
# p00_7df82431132bd479.mp4
# 0
# .\data_subset\p00_7df82431132bd479\faces
# Copying to :.\temp_real_faces\
# p00_08d70553d5255432.mp4
# 0
# .\data_subset\p00_08d70553d5255432\faces
# Copying to :.\temp_real_faces\
# a00_8077b2ca774ae902.mp4
# 0
# .\data_subset\a00_8077b2ca774ae902\faces
# Copying to :.\temp_real_faces\
# a00_4e8dd1d96834b094.mp4
# 0
# .\data_subset\a00_4e8dd1d96834b094\faces
# Copying to :.\temp_real_faces\
# p00_8db0f3a4c3c0a044.mp4
# 0
# .\data_subset\p00_8db0f3a4c3c0a044\faces
# Copying to :.\temp_real_faces\
# a00_9214500ac4a5631b.mp4
# 0
# .\data_subset\a00_9214500ac4a5631b\faces
# Copying to :.\temp_real_faces\
# p00_be24b507a1829cdc.mp4
# 0
# .\data_subset\p00_be24b507a1829cdc\faces
# Copying to :.\temp_real_faces\
# p00_ee3b8d51cc60f0f2.mp4
# 0
# .\data_subset\p00_ee3b8d51cc60f0f2\faces
# Copying to :.\temp_real_faces\
# p00_57f88223b20e916e.mp4
# 0
# .\data_subset\p00_57f88223b20e916e\faces
# Copying to :.\temp_real_faces\
# p00_3ba002dd690806b4.mp4
# 0
# .\data_subset\p00_3ba002dd690806b4\faces
# Copying to :.\temp_real_faces\
# a00_12e04ef780b7e50c.mp4
# 0
# .\data_subset\a00_12e04ef780b7e50c\faces
# Copying to :.\temp_real_faces\
# p00_d517ab9e18f646a7.mp4
# 0
# .\data_subset\p00_d517ab9e18f646a7\faces
# Copying to :.\temp_real_faces\
# p00_e5ee3acf3e77b98b.mp4
# 0
# .\data_subset\p00_e5ee3acf3e77b98b\faces
# Copying to :.\temp_real_faces\
# p00_22a01f2d275af854.mp4
# 0
# .\data_subset\p00_22a01f2d275af854\faces
# Copying to :.\temp_real_faces\
# p00_fcbbfe4be871116b.mp4
# 0
# .\data_subset\p00_fcbbfe4be871116b\faces
# Copying to :.\temp_real_faces\
# p00_16fd19ad3cea06e9.mp4
# 0
# .\data_subset\p00_16fd19ad3cea06e9\faces
# Copying to :.\temp_real_faces\
# a00_7a3e6bd9f4729a03.mp4
# 0
# .\data_subset\a00_7a3e6bd9f4729a03\faces
# Copying to :.\temp_real_faces\
# a00_5111ac0001421265.mp4
# 0
# .\data_subset\a00_5111ac0001421265\faces
# Copying to :.\temp_real_faces\
# p00_b35e3130e27fa1f3.mp4
# 0
# .\data_subset\p00_b35e3130e27fa1f3\faces
# Copying to :.\temp_real_faces\
# a00_5fc20fab79136a9c.mp4
# 0
# .\data_subset\a00_5fc20fab79136a9c\faces
# Copying to :.\temp_real_faces\
# p00_0175e5f022bcabfc.mp4
# 0
# .\data_subset\p00_0175e5f022bcabfc\faces
# Copying to :.\temp_real_faces\
# a00_73d29ce3cfdd5775.mp4
# 0
# .\data_subset\a00_73d29ce3cfdd5775\faces
# Copying to :.\temp_real_faces\
# p00_e515ae44123f42e0.mp4
# 0
# .\data_subset\p00_e515ae44123f42e0\faces
# Copying to :.\temp_real_faces\
# p00_b57a96e8a6eb5db7.mp4
# 0
# .\data_subset\p00_b57a96e8a6eb5db7\faces
# Copying to :.\temp_real_faces\
# a00_601909ccbcfe8f72.mp4
# 0
# .\data_subset\a00_601909ccbcfe8f72\faces
# Copying to :.\temp_real_faces\
# p00_4d279d1a6f1f3f16.mp4
# 0
# .\data_subset\p00_4d279d1a6f1f3f16\faces
# Copying to :.\temp_real_faces\
# a00_30b632439d751e12.mp4
# 0
# .\data_subset\a00_30b632439d751e12\faces
# Copying to :.\temp_real_faces\
# a00_7ffe7480fe24fd74.mp4
# 0
# .\data_subset\a00_7ffe7480fe24fd74\faces
# Copying to :.\temp_real_faces\
# a00_04366168ff44aea3.mp4
# 0
# .\data_subset\a00_04366168ff44aea3\faces
# Copying to :.\temp_real_faces\
# p00_ea6d01464b6b21f8.mp4
# 0
# .\data_subset\p00_ea6d01464b6b21f8\faces
# Copying to :.\temp_real_faces\
# a00_68ae1291eb7dd173.mp4
# 0
# .\data_subset\a00_68ae1291eb7dd173\faces
# Copying to :.\temp_real_faces\
# a00_2f09779a3ab7ffa9.mp4
# 0
# .\data_subset\a00_2f09779a3ab7ffa9\faces
# Copying to :.\temp_real_faces\
# p00_07cc4dde853dfe59.mp4
# 0
# .\data_subset\p00_07cc4dde853dfe59\faces
# Copying to :.\temp_real_faces\
# a00_26e40c6c3cc15101.mp4
# 0
# .\data_subset\a00_26e40c6c3cc15101\faces
# Copying to :.\temp_real_faces\
# a00_dd8abf24ba8b7e51.mp4
# 0
# .\data_subset\a00_dd8abf24ba8b7e51\faces
# Copying to :.\temp_real_faces\
# a00_f4cb6981f1388922.mp4
# 0
# .\data_subset\a00_f4cb6981f1388922\faces
# Copying to :.\temp_real_faces\
# p00_5e1b44064389e170.mp4
# 0
# .\data_subset\p00_5e1b44064389e170\faces
# Copying to :.\temp_real_faces\
# a00_c199f00ba1f77313.mp4
# 0
# .\data_subset\a00_c199f00ba1f77313\faces
# Copying to :.\temp_real_faces\
# p00_afdb22d8f443a3ba.mp4
# 0
# .\data_subset\p00_afdb22d8f443a3ba\faces
# Copying to :.\temp_real_faces\
# p00_dabac5f072e1226f.mp4
# 0
# .\data_subset\p00_dabac5f072e1226f\faces
# Copying to :.\temp_real_faces\
# a00_596b8358e59001e2.mp4
# 0
# .\data_subset\a00_596b8358e59001e2\faces
# Copying to :.\temp_real_faces\
# a00_baa1f106f2cc3603.mp4
# 0
# .\data_subset\a00_baa1f106f2cc3603\faces
# Copying to :.\temp_real_faces\
# p00_c58d5b963323b609.mp4
# 0
# .\data_subset\p00_c58d5b963323b609\faces
# Copying to :.\temp_real_faces\
# p00_399cbe29cdf7083d.mp4
# 0
# .\data_subset\p00_399cbe29cdf7083d\faces
# Copying to :.\temp_real_faces\
# p00_6c0a0280e2613ffc.mp4
# 0
# .\data_subset\p00_6c0a0280e2613ffc\faces
# Copying to :.\temp_real_faces\
# a00_5d38bcd3d823b9ab.mp4
# 0
# .\data_subset\a00_5d38bcd3d823b9ab\faces
# Copying to :.\temp_real_faces\
# a00_c9d51a0f13bc33d9.mp4
# 0
# .\data_subset\a00_c9d51a0f13bc33d9\faces
# Copying to :.\temp_real_faces\
# a00_6f2dbbfa69ef1ee8.mp4
# 0
# .\data_subset\a00_6f2dbbfa69ef1ee8\faces
# Copying to :.\temp_real_faces\
# p00_9e73319675860fe6.mp4
# 0
# .\data_subset\p00_9e73319675860fe6\faces
# Copying to :.\temp_real_faces\
# p00_caaf8bf2b8a714d4.mp4
# 0
# .\data_subset\p00_caaf8bf2b8a714d4\faces
# Copying to :.\temp_real_faces\
# p00_393603a774c3ca2c.mp4
# 0
# .\data_subset\p00_393603a774c3ca2c\faces
# Copying to :.\temp_real_faces\
# a00_c6bf02071cf69c1b.mp4
# 0
# .\data_subset\a00_c6bf02071cf69c1b\faces
# Copying to :.\temp_real_faces\
# p00_b8518ed7b2815d7d.mp4
# 0
# .\data_subset\p00_b8518ed7b2815d7d\faces
# Copying to :.\temp_real_faces\
# a00_3f43f5aa2c76fe0a.mp4
# 0
# .\data_subset\a00_3f43f5aa2c76fe0a\faces
# Copying to :.\temp_real_faces\
# a00_d537cebc922be94c.mp4
# 0
# .\data_subset\a00_d537cebc922be94c\faces
# Copying to :.\temp_real_faces\
# p00_34466a9c7ac27864.mp4
# 0
# .\data_subset\p00_34466a9c7ac27864\faces
# Copying to :.\temp_real_faces\
# a00_594e24957ff83d8d.mp4
# 0
# .\data_subset\a00_594e24957ff83d8d\faces
# Copying to :.\temp_real_faces\
# a00_cf4abd12b74a7013.mp4
# 0
# .\data_subset\a00_cf4abd12b74a7013\faces
# Copying to :.\temp_real_faces\
# a00_f551385f10a66336.mp4
# 0
# .\data_subset\a00_f551385f10a66336\faces
# Copying to :.\temp_real_faces\
# p00_6dad39244c60fc0e.mp4
# 0
# .\data_subset\p00_6dad39244c60fc0e\faces
# Copying to :.\temp_real_faces\
# p00_69995fccede4e6c8.mp4
# 0
# .\data_subset\p00_69995fccede4e6c8\faces
# Copying to :.\temp_real_faces\
# p00_59b4f1a11e25a40a.mp4
# 0
# .\data_subset\p00_59b4f1a11e25a40a\faces
# Copying to :.\temp_real_faces\
# a00_b148049195e7b6d8.mp4
# 0
# .\data_subset\a00_b148049195e7b6d8\faces
# Copying to :.\temp_real_faces\
# a00_102e33c60002e988.mp4
# 0
# .\data_subset\a00_102e33c60002e988\faces
# Copying to :.\temp_real_faces\
# a00_979030a4f5c3da0a.mp4
# 0
# .\data_subset\a00_979030a4f5c3da0a\faces
# Copying to :.\temp_real_faces\
# p00_d2497dfb07bf076a.mp4
# 0
# .\data_subset\p00_d2497dfb07bf076a\faces
# Copying to :.\temp_real_faces\
# a00_77a168e4d0f57f6c.mp4
# 0
# .\data_subset\a00_77a168e4d0f57f6c\faces
# Copying to :.\temp_real_faces\
# p00_8ae490f4751ed5a9.mp4
# 0
# .\data_subset\p00_8ae490f4751ed5a9\faces
# Copying to :.\temp_real_faces\
# p00_ac12a95a62abea14.mp4
# 0
# .\data_subset\p00_ac12a95a62abea14\faces
# Copying to :.\temp_real_faces\
# a00_2644f3c8d89fc12a.mp4
# 0
# .\data_subset\a00_2644f3c8d89fc12a\faces
# Copying to :.\temp_real_faces\
# a00_0ebcff9e9e3dba5d.mp4
# 0
# .\data_subset\a00_0ebcff9e9e3dba5d\faces
# Copying to :.\temp_real_faces\
# p00_87712814ec9ce7e3.mp4
# 0
# .\data_subset\p00_87712814ec9ce7e3\faces
# Copying to :.\temp_real_faces\
# a00_fb5edaa2f8dbfe61.mp4
# 0
# .\data_subset\a00_fb5edaa2f8dbfe61\faces
# Copying to :.\temp_real_faces\
# a00_98085895ca7545f4.mp4
# 0
# .\data_subset\a00_98085895ca7545f4\faces
# Copying to :.\temp_real_faces\
# p00_681fc525a206f128.mp4
# 0
# .\data_subset\p00_681fc525a206f128\faces
# Copying to :.\temp_real_faces\
# p00_6f3c688863a1bb52.mp4
# 0
# .\data_subset\p00_6f3c688863a1bb52\faces
# Copying to :.\temp_real_faces\
# p00_40bf1b90f8f82d2d.mp4
# 0
# .\data_subset\p00_40bf1b90f8f82d2d\faces
# Copying to :.\temp_real_faces\
# p00_de5ba89bdfa8e777.mp4
# 0
# .\data_subset\p00_de5ba89bdfa8e777\faces
# Copying to :.\temp_real_faces\
# p00_69d556df553bdddc.mp4
# 0
# .\data_subset\p00_69d556df553bdddc\faces
# Copying to :.\temp_real_faces\
# a00_c559b389b1535774.mp4
# 0
# .\data_subset\a00_c559b389b1535774\faces
# Copying to :.\temp_real_faces\
# p00_e5047b98b737debd.mp4
# 0
# .\data_subset\p00_e5047b98b737debd\faces
# Copying to :.\temp_real_faces\
# p00_9f4347aa0ff5a39a.mp4
# 0
# .\data_subset\p00_9f4347aa0ff5a39a\faces
# Copying to :.\temp_real_faces\
# a00_951ee63325b9c303.mp4
# 0
# .\data_subset\a00_951ee63325b9c303\faces
# Copying to :.\temp_real_faces\
# p00_2ffa046041106046.mp4
# 0
# .\data_subset\p00_2ffa046041106046\faces
# Copying to :.\temp_real_faces\
# p00_4d6d3ebe3eebfd05.mp4
# 0
# .\data_subset\p00_4d6d3ebe3eebfd05\faces
# Copying to :.\temp_real_faces\
# a00_1e0a2587601a8f13.mp4
# 0
# .\data_subset\a00_1e0a2587601a8f13\faces
# Copying to :.\temp_real_faces\
# a00_e02ac24e1a99284b.mp4
# 0
# .\data_subset\a00_e02ac24e1a99284b\faces
# Copying to :.\temp_real_faces\
# p00_97f332e6c1fc4b01.mp4
# 0
# .\data_subset\p00_97f332e6c1fc4b01\faces
# Copying to :.\temp_real_faces\
# p00_61fe2393735c0e0b.mp4
# 0
# .\data_subset\p00_61fe2393735c0e0b\faces
# Copying to :.\temp_real_faces\
# p00_238e555b9d386eb6.mp4
# 0
# .\data_subset\p00_238e555b9d386eb6\faces
# Copying to :.\temp_real_faces\
# a00_1fe8249533462655.mp4
# 0
# .\data_subset\a00_1fe8249533462655\faces
# Copying to :.\temp_real_faces\
# p00_8511c6ae0f501560.mp4
# 0
# .\data_subset\p00_8511c6ae0f501560\faces
# Copying to :.\temp_real_faces\
# a00_4d63aa9cbc3fac2e.mp4
# 0
# .\data_subset\a00_4d63aa9cbc3fac2e\faces
# Copying to :.\temp_real_faces\
# a00_de3cc28001cb09c4.mp4
# 0
# .\data_subset\a00_de3cc28001cb09c4\faces
# Copying to :.\temp_real_faces\
# a00_2dca441c7ca3490f.mp4
# 0
# .\data_subset\a00_2dca441c7ca3490f\faces
# Copying to :.\temp_real_faces\
# p00_7d87eaecc8de98ef.mp4
# 0
# .\data_subset\p00_7d87eaecc8de98ef\faces
# Copying to :.\temp_real_faces\
# p00_183e7aa54ff16150.mp4
# 0
# .\data_subset\p00_183e7aa54ff16150\faces
# Copying to :.\temp_real_faces\
# a00_4b5d128c68cfa6f5.mp4
# 0
# .\data_subset\a00_4b5d128c68cfa6f5\faces
# Copying to :.\temp_real_faces\
# p00_7bfcca12f5f6caa1.mp4
# 0
# .\data_subset\p00_7bfcca12f5f6caa1\faces
# Copying to :.\temp_real_faces\
# p00_5ac8b33174db90ee.mp4
# 0
# .\data_subset\p00_5ac8b33174db90ee\faces
# Copying to :.\temp_real_faces\
# p00_1cfd80249cce9e44.mp4
# 0
# .\data_subset\p00_1cfd80249cce9e44\faces
# Copying to :.\temp_real_faces\
# p00_b42c644122028ddb.mp4
# 0
# .\data_subset\p00_b42c644122028ddb\faces
# Copying to :.\temp_real_faces\
# p00_5fd73cdccc5e385e.mp4
# 0
# .\data_subset\p00_5fd73cdccc5e385e\faces
# Copying to :.\temp_real_faces\
# a00_cabe7e512ee7d40d.mp4
# 0
# .\data_subset\a00_cabe7e512ee7d40d\faces
# Copying to :.\temp_real_faces\
# a00_6c228a471c167c44.mp4
# 0
# .\data_subset\a00_6c228a471c167c44\faces
# Copying to :.\temp_real_faces\
# p00_8dbb4de72c27723a.mp4
# 0
# .\data_subset\p00_8dbb4de72c27723a\faces
# Copying to :.\temp_real_faces\
# Total Number of Fake faces: 12821 (i.e. 25.53% of all faces)
# Total Number of Real faces: 37403 (i.e. 74.47% of all faces)
# Down-Sampling Done!
# Copying files: 25642 files [06:45, 63.21 files/s]
# Train / Validation / Test Split Done!

# %% [raw]
# @article{chen2022ai,
#   title={AI Singapore Trusted Media Challenge Dataset},
#   author={Chen, Weiling and Chua, Benjamin and Winkler, Stefan},
#   journal={arXiv preprint arXiv:2201.04788},
#   year={2022}
# }
